# %% [markdown]
# # Movies Investment Prediction using a LRM

# %% [markdown]
# Source: Box Office Mojo
# https://www.boxofficemojo.com/

# %% [markdown]
# ##### Web Scrapping

# %% [markdown]
# Let's import our libraries

# %%
#scrapping and cleaning process

from bs4 import BeautifulSoup as BS
import requests
from requests import get
from IPython.core.display import display, HTML
import re
import pandas as pd
import numpy as np
from time import sleep
from random import randint
import dateutil.parser

#visualization

import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_formats = ['svg']  # or svg
# %matplotlib inline

# %% [markdown]
# ## Create functions to grab values

# %%
def get_movie_value(soup, field):
    obj = soup.find(text=re.compile(field))
    if not obj:
        return None
    next_element = obj.findNext()
    if next_element:
        return next_element.text
    else:
        return None

# %%
# Datetime function to parse "datatime" strings into appropriate "Date" data type

def to_date(datestring):
    date = dateutil.parser.parse(datestring)
    return date

# %% [markdown]
# ### Titles

# %%
#Let's start writing functions to get the values we want

def get_movie_title(soup):
    title_element = soup.find("title")
    if not title_element:
        return None

    title_text = title_element.text
    if "-" in title_text:
        title_parts = title_text.split("-")
        if title_parts.count == 2:
            return title_parts[0].strip()
        else:
            return "-".join(title_parts[0:-1]).strip()
    else:
        return title_text.strip()

# %% [markdown]
# ### Runtime

# %%
def get_movie_runtime(soup):
    runtimestring = get_movie_value(soup, "Running")
    try:
        runtime = runtimestring.split()
        minutes = int(runtime[0]) * 60 + int(runtime[2])
        return minutes
    except:
        return None

# %% [markdown]
# ### Widest Release (Theaters)

# %%
def get_movie_widest_release(soup):
    widest_release_value = get_movie_value(soup, "Widest Release")
    if not widest_release_value:
        return None
    widest_release_value = widest_release_value.replace(",", "").split(" ")[0]
    widest_release_value = widest_release_value.strip()
    return int(widest_release_value)

# %% [markdown]
# ### Domestic Gross

# %%
def get_movie_domestic_gross(soup):
    moneystring = (soup.find(class_="mojo-performance-summary-table")
        .find_all("span", class_="money")[0].text)
    moneystring = moneystring.replace("$", "").replace(",", "")
    return int(moneystring)

# %% [markdown]
# ### Budget

# %%
#def get_movie_budget(soup)

def get_movie_budget(soup):
    raw_budget = get_movie_value(soup,"Budget")
    try:
        budget = raw_budget.replace("$", "").replace(",", "")
        return int(budget)
    except:
        return None

# %% [markdown]
# ### Worldwide Gross

# %%
def get_movie_worldwide_gross(soup):
    moneystring = (soup.find(class_="mojo-performance-summary-table")
        .find_all("span", class_="money")[-1].text)
    moneystring = moneystring.replace("$", "").replace(",", "")
    return int(moneystring)

# %% [markdown]
# ### Rating

# %%
def get_movie_rating(soup):
    rating_value = get_movie_value(soup, "MPAA")
    if not rating_value:
        return None
    return rating_value.strip()

# %% [markdown]
# ### Genres

# %%
def get_movie_genres(soup):
    genres_value = get_movie_value(soup, "Genres")
    if not genres_value:
        return None
    genres_value = genres_value.replace('\n    \n       ','')
    return genres_value.strip()

# %% [markdown]
# ### Distributors

# %%
def get_movie_distributor(soup):
    distributor1 = get_movie_value(soup, "Distributor")
    distributor = distributor1.split('See')[0]
    if not distributor:
        return None
    return distributor.strip()

# %% [markdown]
# ### Opening Gross

# %%
def get_movie_opening_gross(soup):
    element1 = soup.find(
        class_="a-section a-spacing-none mojo-summary-values mojo-hidden-from-mobile"
    )
    if not element1:
        return None
    element2 = element1.find("span", class_="money")
    if not element2:
        return None
    opening = element2.text.replace("$", "").replace(",", "")
    return int(opening)

# %% [markdown]
# ### Release Date

# %%
def get_release_date(soup):
    date = get_movie_value(soup, "Release Date").split('-')[0].split('(')[0].strip()
    date = to_date(date)
    if not date:
        return None
    return date

# %% [markdown]
# ### List of Features of all movies

# %%
"""def get_movie_data(url):
    response = requests.get(url)
    page = response.text
    soup = BS(page, "lxml")
    
    title = get_movie_title(soup)
    budget = get_movie_budget(soup)
    runtime = get_movie_runtime(soup)
    rating = get_movie_rating(soup)
    genres = get_movie_genres(soup)
    distributor1 = get_movie_distributor(soup)
    domestic = get_movie_domestic_gross(soup)
    worldwide = get_movie_worldwide_gross(soup)
    opening = get_movie_opening_gross(soup)
    widest_release = get_movie_widest_release(soup)
    release_date = get_release_date(soup)


    headers = ["title", "budget", "runtime", "rating", "genres", "distributor", "domestic_gross", "worldwide_gross", "opening_gross", "widest_release", "release_date"]
    movie_dict = dict(zip(headers, [title, budget, runtime, rating, genres, distributor1, domestic, worldwide, opening, widest_release, release_date]))
    
    return movie_dict"""

# %% [markdown]
# ## Urls for all movies

# %%
"""def get_movie_urls():
    url = "https://www.boxofficemojo.com/year/2019/?ref_=bo_yl_table_3"
    url2 = "https://www.boxofficemojo.com/year/2018/?ref_=bo_yl_table_4"
    url3 = "https://www.boxofficemojo.com/year/2017/?ref_=bo_yl_table_5"
    url4 = "https://www.boxofficemojo.com/year/2016/?ref_=bo_yl_table_6"
    url5 = "https://www.boxofficemojo.com/year/2015/?ref_=bo_yl_table_7"

    url_list = [url, url2, url3, url4, url5]
    
    all_titles = []
    
    for url in url_list:
        page = requests.get(url)
        soup = BS(page.text, "lxml")
        titles = soup.find_all("td", class_="a-text-left mojo-field-type-release mojo-cell-wide")
        for title in titles:
            all_titles.append("https://www.boxofficemojo.com/" + title.select("a")[0].get("href"))
    return all_titles"""

# %%
"urls = get_movie_urls()"

# %%
"urls"
# Out:
# ['https://www.boxofficemojo.com//release/rl3059975681/?ref_=bo_yld_table_1',
#  'https://www.boxofficemojo.com//release/rl3321923073/?ref_=bo_yld_table_2',
#  'https://www.boxofficemojo.com//release/rl3798500865/?ref_=bo_yld_table_3',
#  'https://www.boxofficemojo.com//release/rl2424210945/?ref_=bo_yld_table_4',
#  'https://www.boxofficemojo.com//release/rl3009644033/?ref_=bo_yld_table_5',
#  'https://www.boxofficemojo.com//release/rl3305145857/?ref_=bo_yld_table_6',
#  'https://www.boxofficemojo.com//release/rl3791750657/?ref_=bo_yld_table_7',
#  'https://www.boxofficemojo.com//release/rl3246360065/?ref_=bo_yld_table_8',
#  'https://www.boxofficemojo.com//release/rl252151297/?ref_=bo_yld_table_9',
#  'https://www.boxofficemojo.com//release/rl1107461633/?ref_=bo_yld_table_10',
#  'https://www.boxofficemojo.com//release/rl755467777/?ref_=bo_yld_table_11',
#  'https://www.boxofficemojo.com//release/rl1711506945/?ref_=bo_yld_table_12',
#  'https://www.boxofficemojo.com//release/rl793544193/?ref_=bo_yld_table_170',
#  'https://www.boxofficemojo.com//release/rl2623047169/?ref_=bo_yld_table_171',
#  'https://www.boxofficemojo.com//release/rl3648816641/?ref_=bo_yld_table_172',
#  'https://www.boxofficemojo.com//release/rl75269633/?ref_=bo_yld_table_173',
#  'https://www.boxofficemojo.com//release/rl2105050625/?ref_=bo_yld_table_174',
#  'https://www.boxofficemojo.com//release/rl1398441473/?ref_=bo_yld_table_175',
#  'https://www.boxofficemojo.com//release/rl1279821313/?ref_=bo_yld_table_176',
#  'https://www.boxofficemojo.com//release/rl3547301377/?ref_=bo_yld_table_177',
#  'https://www.boxofficemojo.com//release/rl3896542721/?ref_=bo_yld_table_178',
#  'https://www.boxofficemojo.com//release/rl3698361857/?ref_=bo_yld_table_179',
#  'https://www.boxofficemojo.com//release/rl3178792449/?ref_=bo_yld_table_180',
#  'https://www.boxofficemojo.com//release/rl2272822785/?ref_=bo_yld_table_181',
#  'https://www.boxofficemojo.com//release/rl3378480641/?ref_=bo_yld_table_182',
#  'https://www.boxofficemojo.com//release/rl3915744769/?ref_=bo_yld_table_183',
#  'https://www.boxofficemojo.com//release/rl3211298305/?ref_=bo_yld_table_184',
#  'https://www.boxofficemojo.com//release/rl628983297/?ref_=bo_yld_table_185',
#  'https://www.boxofficemojo.com//release/rl729581057/?ref_=bo_yld_table_186',
#  'https://www.boxofficemojo.com//release/rl2826274305/?ref_=bo_yld_table_187',
#  'https://www.boxofficemojo.com//release/rl1147962881/?ref_=bo_yld_table_188',
#  'https://www.boxofficemojo.com//release/rl4283532801/?ref_=bo_yld_table_189',
#  'https://www.boxofficemojo.com//release/rl3195766273/?ref_=bo_yld_table_190',
#  'https://www.boxofficemojo.com//release/rl559449601/?ref_=bo_yld_table_191',
#  'https://www.boxofficemojo.com//release/rl4083189249/?ref_=bo_yld_table_192',
#  'https://www.boxofficemojo.com//release/rl1783137793/?ref_=bo_yld_table_193',
#  'https://www.boxofficemojo.com//release/rl1115457025/?ref_=bo_yld_table_194',
#  'https://www.boxofficemojo.com//release/rl559580673/?ref_=bo_yld_table_195',
#  'https://www.boxofficemojo.com//release/rl1316849153/?ref_=bo_yld_table_196',
#  'https://www.boxofficemojo.com//release/rl3462563329/?ref_=bo_yld_table_197',
#  'https://www.boxofficemojo.com//release/rl1063814657/?ref_=bo_yld_table_198',
#  'https://www.boxofficemojo.com//release/rl1648461313/?ref_=bo_yld_table_199',
#  'https://www.boxofficemojo.com//release/rl2793244161/?ref_=bo_yld_table_200']

# %% [markdown]
# ### Counter I

# %%
"""#Let's run the data to see if we get any error

count = 1
for url in urls:
    print(f"{count}: {url}")
    movie_data = get_movie_data(url)
    print(movie_data)
    count = count + 1
#   sleep(randint(1, 2))"""
# Out:
# '#Let\'s run the data to see if we get any error\n\ncount = 1\nfor url in urls:\n    print(f"{count}: {url}")\n    movie_data = get_movie_data(url)\n    print(movie_data)\n    count = count + 1\n#   sleep(randint(1, 2))'

# %% [markdown]
# ## Additional Scraping

# %% [markdown]
# ### Cast and Crew

# %% [markdown]
# ### Link for Top Movies

# %%
def get_movie_links():
    link1 = "https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=G"
    link2 = "https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=G&offset=200"
    link3 = "https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=G%2FPG"
    link4 = "https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=G%2FPG&offset=200"
    link5 = "https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=G%2FPG&offset=400"
    link6 = "https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=G%2FPG&offset=600"
    link7 = "https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=G%2FPG&offset=800"
    link8 = "https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=PG"
    link9 = "https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=PG&offset=200"
    link10 = "https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=PG&offset=400"
    link11 = "https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=PG&offset=600"
    link12 = "https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=PG&offset=800"
    link13 = "https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=PG-13"
    link14 = "https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=PG-13&offset=200"
    link15 = "https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=PG-13&offset=400"
    link16 = "https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=PG-13&offset=600"
    link17 = "https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=PG-13&offset=800"
    link18 = "https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=R"
    link19 = "https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=R&offset=200"
    link20 = "https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=R&offset=400"
    link21 = "https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=R&offset=600"
    link22 = "https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=R&offset=800"

    link_list = [link1, link2, link3, link4, link5, link6, link7, link8, link9, link10, link11, link12, link13, link14, link15, link16, link17, link18, link19, link20, link21, link22]
    
    all_titles = []
    
    for link in link_list:
        page = requests.get(link)
        soup = BS(page.text, "lxml")
        titles = soup.find_all("td", class_="a-text-left mojo-header-column mojo-truncate mojo-field-type-title")
        for title in titles:
            all_titles.append("https://www.boxofficemojo.com/" + title.select("a")[0].get("href"))
    return all_titles

# %%
links = get_movie_links()

# %%
print(len(links))
# Out:
# 4364

# %%
links
# Out:
# ['https://www.boxofficemojo.com//title/tt1979376/?ref_=bo_cso_table_1',
#  'https://www.boxofficemojo.com//title/tt0110357/?ref_=bo_cso_table_2',
#  'https://www.boxofficemojo.com//title/tt0435761/?ref_=bo_cso_table_3',
#  'https://www.boxofficemojo.com//title/tt0266543/?ref_=bo_cso_table_4',
#  'https://www.boxofficemojo.com//title/tt0198781/?ref_=bo_cso_table_5',
#  'https://www.boxofficemojo.com//title/tt1453405/?ref_=bo_cso_table_6',
#  'https://www.boxofficemojo.com//title/tt0120363/?ref_=bo_cso_table_7',
#  'https://www.boxofficemojo.com//title/tt0317219/?ref_=bo_cso_table_8',
#  'https://www.boxofficemojo.com//title/tt0910970/?ref_=bo_cso_table_9',
#  'https://www.boxofficemojo.com//title/tt0114709/?ref_=bo_cso_table_10',
#  'https://www.boxofficemojo.com//title/tt0101414/?ref_=bo_cso_table_11',
#  'https://www.boxofficemojo.com//title/tt0103639/?ref_=bo_cso_table_12',
#  'https://www.boxofficemojo.com//title/tt0382932/?ref_=bo_cso_table_13',
#  'https://www.boxofficemojo.com//title/tt0031381/?ref_=bo_cso_table_14',
#  'https://www.boxofficemojo.com//title/tt1216475/?ref_=bo_cso_table_15',
#  'https://www.boxofficemojo.com//title/tt0338348/?ref_=bo_cso_table_16',
#  'https://www.boxofficemojo.com//title/tt0029583/?ref_=bo_cso_table_17',
#  'https://www.boxofficemojo.com//title/tt0120855/?ref_=bo_cso_table_18',
#  'https://www.boxofficemojo.com//title/tt0120623/?ref_=bo_cso_table_19',
#  'https://www.boxofficemojo.com//title/tt0059742/?ref_=bo_cso_table_20',
#  'https://www.boxofficemojo.com//title/tt0451079/?ref_=bo_cso_table_21',
#  'https://www.boxofficemojo.com//title/tt3606752/?ref_=bo_cso_table_22',
#  'https://www.boxofficemojo.com//title/tt0083791/?ref_=bo_cso_table_14',
#  'https://www.boxofficemojo.com//title/tt0095253/?ref_=bo_cso_table_15',
#  'https://www.boxofficemojo.com//title/tt0281358/?ref_=bo_cso_table_16',
#  'https://www.boxofficemojo.com//title/tt0082186/?ref_=bo_cso_table_17',
#  'https://www.boxofficemojo.com//title/tt0760329/?ref_=bo_cso_table_18',
#  'https://www.boxofficemojo.com//title/tt0089791/?ref_=bo_cso_table_19',
#  'https://www.boxofficemojo.com//title/tt4587656/?ref_=bo_cso_table_20',
#  'https://www.boxofficemojo.com//title/tt4468740/?ref_=bo_cso_table_21',
#  'https://www.boxofficemojo.com//title/tt0088850/?ref_=bo_cso_table_22',
#  'https://www.boxofficemojo.com//title/tt0081974/?ref_=bo_cso_table_23',
#  'https://www.boxofficemojo.com//title/tt7083526/?ref_=bo_cso_table_24',
#  'https://www.boxofficemojo.com//title/tt0091949/?ref_=bo_cso_table_25',
#  'https://www.boxofficemojo.com//title/tt0104187/?ref_=bo_cso_table_26',
#  'https://www.boxofficemojo.com//title/tt0096928/?ref_=bo_cso_table_27',
#  'https://www.boxofficemojo.com//title/tt0086837/?ref_=bo_cso_table_28',
#  'https://www.boxofficemojo.com//title/tt0295427/?ref_=bo_cso_table_29',
#  'https://www.boxofficemojo.com//title/tt0082979/?ref_=bo_cso_table_30',
#  'https://www.boxofficemojo.com//title/tt0054357/?ref_=bo_cso_table_31',
#  'https://www.boxofficemojo.com//title/tt0086619/?ref_=bo_cso_table_32',
#  'https://www.boxofficemojo.com//title/tt0094739/?ref_=bo_cso_table_33',
#  'https://www.boxofficemojo.com//title/tt0282120/?ref_=bo_cso_table_34',
#  'https://www.boxofficemojo.com//title/tt0113755/?ref_=bo_cso_table_35',
#  'https://www.boxofficemojo.com//title/tt0093886/?ref_=bo_cso_table_36',
#  ...]

# %% [markdown]
# ### List of Features of top movies (Cast and Crew)

# %% [markdown]
# ### Extracting Titles for Cast and Crew values

# %%
def get_movie_titles2(url):
    response = requests.get(url)
    page = response.text
    soup = BS(page, "lxml")
    
    titles = []

    title_text = (soup.find("h1", class_="a-size-extra-large").text[:-7])

    for title in title_text.split("\n"):
        titles.append(title)

    return(titles)

# %% [markdown]
# ### Years

# %%
def get_movie_year2(url):
    response = requests.get(url)
    page = response.text
    soup = BS(page, "lxml")
    
    years = []

    year_text = (soup.find("h1", class_="a-size-extra-large").text[-5:-1])

    for year in year_text.split("\n"):
        years.append(year)

    return(years)

# %% [markdown]
# ### Extracting Directors from principalCrew table

# %%
def get_movie_director2(url):
    response = requests.get(url)
    page = response.text
    soup = BS(page, "lxml")
    
    directors = []

    crew_string = (soup.find(id="principalCrew").find_all("tr"))

    for crew_member in crew_string:
        if 'Director' in crew_member.text:
            directors.append(crew_member.text.replace('Director','').replace('\n', ''))

    return(directors)

# %% [markdown]
# ### Extracting Actors from principalCast table

# %%
def get_movie_actors2(url):
    response = requests.get(url)
    page = response.text
    soup = BS(page, "lxml")
    
    actors = []

    actors_string = (soup.find(id="principalCast").find_all("tr"))

    for actor in actors_string[1:]:
        stop_point = actor.text.find('\n')
        actors.append(actor.text[:stop_point])

    return(actors)

# %% [markdown]
# ### New links for actors and directors table

# %%
to_append = 'credits/?ref_=bo_tt_tab#tabs'
new_links = [link[:link.find('?ref')] + to_append for link in links]

# %%
links[5]
# Out:
# 'https://www.boxofficemojo.com//title/tt1453405/?ref_=bo_cso_table_6'

# %%
new_links[5]
# Out:
# 'https://www.boxofficemojo.com//title/tt1453405/credits/?ref_=bo_tt_tab#tabs'

# %% [markdown]
# ### new pipeline for directors and actors data

# %%
def get_movie_data2(url):
    
    title = get_movie_titles2(url)
    director = get_movie_director2(url)
    actors = get_movie_actors2(url)
    years = get_movie_year2(url)

    headers = ["title", "director", "actors", "years"]
    movie_dict = dict(zip(headers, [title, director, actors, years]))
    
    return movie_dict

# %% [markdown]
# ### test new pipeline with new urls

# %%
new_links[10]
# Out:
# 'https://www.boxofficemojo.com//title/tt0101414/credits/?ref_=bo_tt_tab#tabs'

# %%
get_movie_data2(new_links[10])
# Out:
# {'title': ['Beauty and the Beast'],
#  'director': ['Gary Trousdale', 'Kirk Wise'],
#  'actors': ["Paige O'Hara", 'Robby Benson', 'Jesse Corti', 'Rex Everhart'],
#  'years': ['1991']}

# %% [markdown]
# ### test against all new urls

# %%
for link in new_links[:5]:
    print(get_movie_data2(link))
# Out:
# {'title': ['Toy Story 4'], 'director': ['Josh Cooley'], 'actors': ['Tom Hanks', 'Tim Allen', 'Annie Potts', 'Tony Hale'], 'years': ['2019']}
# {'title': ['The Lion King'], 'director': ['Roger Allers', 'Rob Minkoff'], 'actors': ['Matthew Broderick', 'Jeremy Irons', 'James Earl Jones', 'Whoopi Goldberg'], 'years': ['1994']}
# {'title': ['Toy Story 3'], 'director': ['Lee Unkrich'], 'actors': ['Tom Hanks', 'Tim Allen', 'Joan Cusack', 'Ned Beatty'], 'years': ['2010']}
# {'title': ['Finding Nemo'], 'director': ['Andrew Stanton', 'Lee Unkrich'], 'actors': ['Albert Brooks', 'Ellen DeGeneres', 'Alexander Gould', 'Willem Dafoe'], 'years': ['2003']}
# {'title': ['Monsters, Inc.'], 'director': ['Pete Docter', 'David Silverman', 'Lee Unkrich'], 'actors': ['Billy Crystal', 'John Goodman', 'Mary Gibbs', 'Steve Buscemi'], 'years': ['2001']}

# %% [markdown]
# ### Counter II (Cast and Crew)

# %%
"""#Let's run the data to see if we get any error

count = 1
for link in new_links:
    print(f"{count}: {link}")
    movie_data2 = get_movie_data2(link)
    print(movie_data2)
    count = count + 1
#    sleep(randint(1, 2))"""
# Out:
# '#Let\'s run the data to see if we get any error\n\ncount = 1\nfor link in new_links:\n    print(f"{count}: {link}")\n    movie_data2 = get_movie_data2(link)\n    print(movie_data2)\n    count = count + 1\n#    sleep(randint(1, 2))'

# %%
movies_crewcast_list = []

for link in new_links:
    movies_crewcast_list.append(get_movie_data2(link)) # 3:24 - 4:04

# %%
movies_crewcast = pd.DataFrame(movies_crewcast_list)  #convert list of dict to df

# %%
movies_crewcast.shape
# Out:
# (4364, 4)

# %%
movies_crewcast.to_csv('/Users/hernantrujillo/Documents/Metis/NBM_Regression_Student-main/Movies_Project_Hernan/data_project/crew_cast_raw.csv')

# %%
movies_crewcast = pd.read_csv("/Users/hernantrujillo/Documents/Metis/NBM_Regression_Student-main/Movies_Project_Hernan/data_project/crew_cast_raw.csv")

# %%
movies_crewcast.head()
# Out:
#    Unnamed: 0               title  \
# 0           0     ['Toy Story 4']
# 1           1   ['The Lion King']
# 2           2     ['Toy Story 3']
# 3           3    ['Finding Nemo']
# 4           4  ['Monsters, Inc.']
#
#                                             director  \
# 0                                    ['Josh Cooley']
# 1                    ['Roger Allers', 'Rob Minkoff']
# 2                                    ['Lee Unkrich']
# 3                  ['Andrew Stanton', 'Lee Unkrich']
# 4  ['Pete Docter', 'David Silverman', 'Lee Unkrich']
#
#                                               actors     years
# 0  ['Tom Hanks', 'Tim Allen', 'Annie Potts', 'Ton...  ['2019']
# 1  ['Matthew Broderick', 'Jeremy Irons', 'James E...  ['1994']
# 2  ['Tom Hanks', 'Tim Allen', 'Joan Cusack', 'Ned...  ['2010']
# 3  ['Albert Brooks', 'Ellen DeGeneres', 'Alexande...  ['2003']
# 4  ['Billy Crystal', 'John Goodman', 'Mary Gibbs'...  ['2001']

# %%
# remove outside brackets (years)

movies_crewcast['years'] = movies_crewcast.years.astype(str)
movies_crewcast['years'] = movies_crewcast['years'].str.replace(']','').str.replace('[','').str.replace('\'', '')
movies_crewcast.head()
# Out:
#    Unnamed: 0               title  \
# 0           0     ['Toy Story 4']
# 1           1   ['The Lion King']
# 2           2     ['Toy Story 3']
# 3           3    ['Finding Nemo']
# 4           4  ['Monsters, Inc.']
#
#                                             director  \
# 0                                    ['Josh Cooley']
# 1                    ['Roger Allers', 'Rob Minkoff']
# 2                                    ['Lee Unkrich']
# 3                  ['Andrew Stanton', 'Lee Unkrich']
# 4  ['Pete Docter', 'David Silverman', 'Lee Unkrich']
#
#                                               actors years
# 0  ['Tom Hanks', 'Tim Allen', 'Annie Potts', 'Ton...  2019
# 1  ['Matthew Broderick', 'Jeremy Irons', 'James E...  1994
# 2  ['Tom Hanks', 'Tim Allen', 'Joan Cusack', 'Ned...  2010
# 3  ['Albert Brooks', 'Ellen DeGeneres', 'Alexande...  2003
# 4  ['Billy Crystal', 'John Goodman', 'Mary Gibbs'...  2001

# %%
# remove outside brackets and quotes (title)

movies_crewcast['title'] = movies_crewcast.title.astype(str)
movies_crewcast['title'] = movies_crewcast['title'].str.replace(']','').str.replace('[','').str.replace('\'', '').str.replace('"', '')
movies_crewcast.head()
# Out:
#    Unnamed: 0           title  \
# 0           0     Toy Story 4
# 1           1   The Lion King
# 2           2     Toy Story 3
# 3           3    Finding Nemo
# 4           4  Monsters, Inc.
#
#                                             director  \
# 0                                    ['Josh Cooley']
# 1                    ['Roger Allers', 'Rob Minkoff']
# 2                                    ['Lee Unkrich']
# 3                  ['Andrew Stanton', 'Lee Unkrich']
# 4  ['Pete Docter', 'David Silverman', 'Lee Unkrich']
#
#                                               actors years
# 0  ['Tom Hanks', 'Tim Allen', 'Annie Potts', 'Ton...  2019
# 1  ['Matthew Broderick', 'Jeremy Irons', 'James E...  1994
# 2  ['Tom Hanks', 'Tim Allen', 'Joan Cusack', 'Ned...  2010
# 3  ['Albert Brooks', 'Ellen DeGeneres', 'Alexande...  2003
# 4  ['Billy Crystal', 'John Goodman', 'Mary Gibbs'...  2001

# %%
movies_crewcast.set_index('title', inplace=True) #indexing by movie title

movies_crewcast
# Out:
#                           Unnamed: 0  \
# title
# Toy Story 4                        0
# The Lion King                      1
# Toy Story 3                        2
# Finding Nemo                       3
# Monsters, Inc.                     4
# ...                              ...
# Hannibal Rising                 4359
# Cadillac Man                    4360
# Do the Right Thing              4361
# Poetic Justice                  4362
# Three Days of the Condor        4363
#
#                                                                    director  \
# title
# Toy Story 4                                                 ['Josh Cooley']
# The Lion King                               ['Roger Allers', 'Rob Minkoff']
# Toy Story 3                                                 ['Lee Unkrich']
# Finding Nemo                              ['Andrew Stanton', 'Lee Unkrich']
# Monsters, Inc.            ['Pete Docter', 'David Silverman', 'Lee Unkrich']
# ...                                                                     ...
# Hannibal Rising                                            ['Peter Webber']
# Cadillac Man                                            ['Roger Donaldson']
# Do the Right Thing                                            ['Spike Lee']
# Poetic Justice                                           ['John Singleton']
# Three Days of the Condor                                 ['Sydney Pollack']
#
#                                                                      actors  \
# title
# Toy Story 4               ['Tom Hanks', 'Tim Allen', 'Annie Potts', 'Ton...
# The Lion King             ['Matthew Broderick', 'Jeremy Irons', 'James E...
# Toy Story 3               ['Tom Hanks', 'Tim Allen', 'Joan Cusack', 'Ned...
# Finding Nemo              ['Albert Brooks', 'Ellen DeGeneres', 'Alexande...
# Monsters, Inc.            ['Billy Crystal', 'John Goodman', 'Mary Gibbs'...
# ...                                                                     ...
# Hannibal Rising           ['Gaspard Ulliel', 'Rhys Ifans', 'Gong Li', 'A...
# Cadillac Man              ['Robin Williams', 'Tim Robbins', 'Pamela Reed...
# Do the Right Thing        ['Danny Aiello', 'Ossie Davis', 'Ruby Dee', 'R...
# Poetic Justice            ['Janet Jackson', 'Tupac Shakur', 'Regina King...
# Three Days of the Condor  ['Robert Redford', 'Faye Dunaway', 'Cliff Robe...
#
#                          years
# title
# Toy Story 4               2019
# The Lion King             1994
# Toy Story 3               2010
# Finding Nemo              2003
# Monsters, Inc.            2001
# ...                        ...
# Hannibal Rising           2007
# Cadillac Man              1990
# Do the Right Thing        1989
# Poetic Justice            1993
# Three Days of the Condor  1975
#
# [4364 rows x 4 columns]

# %%
movies_crewcast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4364 entries, Toy Story 4 to Three Days of the Condor
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4364 non-null   int64
#  1   director    4364 non-null   object
#  2   actors      4364 non-null   object
#  3   years       4364 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 170.5+ KB

# %%
# remove outside brackets and quotes (directors)
movies_crewcast['director'] = movies_crewcast.director.astype(str)
movies_crewcast['director'] = movies_crewcast['director'].str.replace(']','').str.replace('[','').str.replace('\'', '').str.replace('"', '')
movies_crewcast.head()
# Out:
#                 Unnamed: 0                                   director  \
# title
# Toy Story 4              0                                Josh Cooley
# The Lion King            1                  Roger Allers, Rob Minkoff
# Toy Story 3              2                                Lee Unkrich
# Finding Nemo             3                Andrew Stanton, Lee Unkrich
# Monsters, Inc.           4  Pete Docter, David Silverman, Lee Unkrich
#
#                                                            actors years
# title
# Toy Story 4     ['Tom Hanks', 'Tim Allen', 'Annie Potts', 'Ton...  2019
# The Lion King   ['Matthew Broderick', 'Jeremy Irons', 'James E...  1994
# Toy Story 3     ['Tom Hanks', 'Tim Allen', 'Joan Cusack', 'Ned...  2010
# Finding Nemo    ['Albert Brooks', 'Ellen DeGeneres', 'Alexande...  2003
# Monsters, Inc.  ['Billy Crystal', 'John Goodman', 'Mary Gibbs'...  2001

# %%
# remove outside brackets and quotes (actors)
movies_crewcast['actors'] = movies_crewcast.actors.astype(str)
movies_crewcast['actors'] = movies_crewcast['actors'].str.replace(']','').str.replace('[','').str.replace('\'', '').str.replace('"', '')
movies_crewcast.head()
# Out:
#                 Unnamed: 0                                   director  \
# title
# Toy Story 4              0                                Josh Cooley
# The Lion King            1                  Roger Allers, Rob Minkoff
# Toy Story 3              2                                Lee Unkrich
# Finding Nemo             3                Andrew Stanton, Lee Unkrich
# Monsters, Inc.           4  Pete Docter, David Silverman, Lee Unkrich
#
#                                                            actors years
# title
# Toy Story 4          Tom Hanks, Tim Allen, Annie Potts, Tony Hale  2019
# The Lion King   Matthew Broderick, Jeremy Irons, James Earl Jo...  1994
# Toy Story 3         Tom Hanks, Tim Allen, Joan Cusack, Ned Beatty  2010
# Finding Nemo    Albert Brooks, Ellen DeGeneres, Alexander Goul...  2003
# Monsters, Inc.  Billy Crystal, John Goodman, Mary Gibbs, Steve...  2001

# %%
movies_crewcast.columns
# Out:
# Index(['Unnamed: 0', 'director', 'actors', 'years'], dtype='object')

# %%
"""movies_list = []   #<- make an empty list
for url in urls:   #<- url list
    movies_list.append(get_movie_data(url)) #4:40 - 4:55"""

# %%
#movies_list
# Out:
# [{'title': 'Avengers: Endgame',
#   'budget': 356000000,
#   'runtime': 181,
#   'rating': 'PG-13',
#   'genres': 'Action Adventure Drama Sci-Fi',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'domestic_gross': 858373000,
#   'worldwide_gross': 2797501328,
#   'opening_gross': 357115007,
#   'widest_release': 4662,
#   'release_date': datetime.datetime(2019, 4, 26, 0, 0)},
#  {'title': 'The Lion King',
#   'budget': 260000000,
#   'runtime': 118,
#   'rating': 'PG',
#   'genres': 'Adventure Animation Drama Family Musical',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'domestic_gross': 543638043,
#   'worldwide_gross': 1656943394,
#   'opening_gross': 191770759,
#   'widest_release': 4802,
#   'release_date': datetime.datetime(2019, 7, 19, 0, 0)},
#  {'title': 'Toy Story 4',
#   'budget': 200000000,
#   'runtime': 100,
#   'rating': 'G',
#   'genres': 'Adventure Animation Comedy Family Fantasy',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'domestic_gross': 434038008,
#   'worldwide_gross': 1073394593,
#   'opening_gross': 120908065,
#   'widest_release': 4575,
#   'release_date': datetime.datetime(2019, 6, 21, 0, 0)},
#  {'title': 'Frozen II',
#   'budget': 150000000,
#   'runtime': 103,
#   'rating': 'PG',
#   'genres': 'Adventure Animation Comedy Family Fantasy Musical',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'domestic_gross': 477373578,
#   'worldwide_gross': 1450026933,
#   'opening_gross': 130263358,
#   'widest_release': 4440,
#   'release_date': datetime.datetime(2019, 11, 22, 0, 0)},
#  {'title': 'Captain Marvel',
#   'budget': 160000000,
#   'runtime': 123,
#   'rating': 'PG-13',
#   'genres': 'Action Adventure Sci-Fi',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'domestic_gross': 426829839,
#   'worldwide_gross': 1128274794,
#   'opening_gross': 153433423,
#   'widest_release': 4310,
#   'release_date': datetime.datetime(2019, 3, 8, 0, 0)},
#  {'title': 'Star Wars: Episode IX - The Rise of Skywalker',
#   'budget': 275000000,
#   'runtime': 141,
#   'rating': 'PG-13',
#   'genres': 'Action Adventure Fantasy Sci-Fi',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'domestic_gross': 515202542,
#   'worldwide_gross': 1074144248,
#   'opening_gross': 177383864,
#   'widest_release': 4406,
#   'release_date': datetime.datetime(2019, 12, 20, 0, 0)},
#  {'title': 'Spider-Man: Far from Home',
#   'budget': 160000000,
#   'runtime': 129,
#   'rating': 'PG-13',
#   'genres': 'Action Adventure Sci-Fi',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'domestic_gross': 390532085,
#   'worldwide_gross': 1131927996,
#   'opening_gross': 92579212,
#   'widest_release': 4634,
#   'release_date': datetime.datetime(2019, 7, 2, 0, 0)},
#  {'title': 'Aladdin',
#   'budget': 183000000,
#   'runtime': 128,
#   'rating': 'PG',
#   'genres': 'Adventure Family Fantasy Musical Romance',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'domestic_gross': 355559216,
#   'worldwide_gross': 1050693953,
#   'opening_gross': 91500929,
#   'widest_release': 4476,
#   'release_date': datetime.datetime(2019, 5, 24, 0, 0)},
#  {'title': 'Joker',
#   'budget': 55000000,
#   'runtime': 122,
#   'rating': 'R',
#   'genres': 'Crime Drama Thriller',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 335451311,
#   'worldwide_gross': 1074251311,
#   'opening_gross': 96202337,
#   'widest_release': 4374,
#   'release_date': datetime.datetime(2019, 10, 4, 0, 0)},
#  {'title': 'It Chapter Two',
#   'budget': 79000000,
#   'runtime': 169,
#   'rating': 'R',
#   'genres': 'Drama Fantasy Horror',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 211593228,
#   'worldwide_gross': 473093228,
#   'opening_gross': 91062152,
#   'widest_release': 4570,
#   'release_date': datetime.datetime(2019, 9, 6, 0, 0)},
#  {'title': 'Jumanji: The Next Level',
#   'budget': 125000000,
#   'runtime': 123,
#   'rating': 'PG-13',
#   'genres': 'Action Adventure Comedy Fantasy',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'domestic_gross': 320314960,
#   'worldwide_gross': 800059707,
#   'opening_gross': 59251543,
#   'widest_release': 4227,
#   'release_date': datetime.datetime(2019, 12, 13, 0, 0)},
#  {'title': 'Us',
#   'budget': 20000000,
#   'runtime': 116,
#   'rating': 'R',
#   'genres': 'Horror Mystery Thriller',
#   'distributor': 'Universal Pictures',
#   'domestic_gross': 175084580,
#   'worldwide_gross': 255184580,
#   'opening_gross': 71117625,
#   'widest_release': 3743,
#   'release_date': datetime.datetime(2019, 3, 22, 0, 0)},
#  {'title': 'Fast & Furious Presents: Hobbs & Shaw',
#   'budget': 200000000,
#   'runtime': 137,
#   'rating': None,
#   'genres': 'Action Adventure Thriller',
#   'distributor': 'Universal Pictures',
#   'domestic_gross': 173956935,
#   'worldwide_gross': 759056935,
#   'opening_gross': 60038950,
#   'widest_release': 4344,
#   'release_date': datetime.datetime(2019, 8, 2, 0, 0)},
#  {'title': 'John Wick: Chapter 3 - Parabellum',
#   'budget': 75000000,
#   'runtime': 130,
#   'rating': 'R',
#   'genres': 'Action Crime Thriller',
#   'distributor': 'Lionsgate',
#   'domestic_gross': 171015687,
#   'worldwide_gross': 326709727,
#   'opening_gross': 56818067,
#   'widest_release': 3850,
#   'release_date': datetime.datetime(2019, 5, 17, 0, 0)},
#  {'title': 'How to Train Your Dragon: The Hidden World',
#   'budget': 129000000,
#   'runtime': 104,
#   'rating': 'PG',
#   'genres': 'Action Adventure Animation Drama Family Fantasy',
#   'distributor': 'Universal Pictures',
#   'domestic_gross': 160799505,
#   'worldwide_gross': 521799505,
#   'opening_gross': 55022245,
#   'widest_release': 4286,
#   'release_date': datetime.datetime(2019, 2, 22, 0, 0)},
#  {'title': 'The Secret Life of Pets 2',
#   'budget': 80000000,
#   'runtime': 86,
#   'rating': 'PG',
#   'genres': 'Adventure Animation Comedy Family',
#   'distributor': 'Universal Pictures',
#   'domestic_gross': 158874395,
#   'worldwide_gross': 430051293,
#   'opening_gross': 46652680,
#   'widest_release': 4564,
#   'release_date': datetime.datetime(2019, 6, 7, 0, 0)},
#  {'title': 'Pokémon Detective Pikachu',
#   'budget': 150000000,
#   'runtime': 104,
#   'rating': 'PG',
#   'genres': 'Action Adventure Comedy Family Mystery Sci-Fi',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 144105346,
#   'worldwide_gross': 433005346,
#   'opening_gross': 54365242,
#   'widest_release': 4248,
#   'release_date': datetime.datetime(2019, 5, 10, 0, 0)},
#  {'title': 'Once Upon a Time... In Hollywood',
#   'budget': 90000000,
#   'runtime': 161,
#   'rating': 'R',
#   'genres': 'Comedy Drama',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'domestic_gross': 142502728,
#   'worldwide_gross': 374375059,
#   'opening_gross': 41082018,
#   'widest_release': 3659,
#   'release_date': datetime.datetime(2019, 7, 26, 0, 0)},
#  {'title': 'Shazam!',
#   'budget': 100000000,
#   'runtime': 132,
#   'rating': 'PG-13',
#   'genres': 'Action Adventure Comedy Fantasy',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 140371656,
#   'worldwide_gross': 365971656,
#   'opening_gross': 53505326,
#   'widest_release': 4306,
#   'release_date': datetime.datetime(2019, 4, 5, 0, 0)},
#  {'title': 'Aquaman',
#   'budget': None,
#   'runtime': 143,
#   'rating': 'PG-13',
#   'genres': 'Action Adventure Fantasy Sci-Fi',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 335061807,
#   'worldwide_gross': 1148461807,
#   'opening_gross': 67873522,
#   'widest_release': 4184,
#   'release_date': datetime.datetime(2018, 12, 21, 0, 0)},
#  {'title': 'Knives Out',
#   'budget': 40000000,
#   'runtime': 130,
#   'rating': 'PG-13',
#   'genres': 'Comedy Crime Drama Mystery Thriller',
#   'distributor': 'Lionsgate',
#   'domestic_gross': 165363234,
#   'worldwide_gross': 311539397,
#   'opening_gross': 26769548,
#   'widest_release': 3461,
#   'release_date': datetime.datetime(2019, 11, 27, 0, 0)},
#  {'title': 'Dumbo',
#   'budget': 170000000,
#   'runtime': 112,
#   'rating': 'PG',
#   'genres': 'Adventure Family Fantasy',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'domestic_gross': 114766307,
#   'worldwide_gross': 353284621,
#   'opening_gross': 45990748,
#   'widest_release': 4259,
#   'release_date': datetime.datetime(2019, 3, 29, 0, 0)},
#  {'title': 'Maleficent: Mistress of Evil',
#   'budget': 185000000,
#   'runtime': 119,
#   'rating': 'PG',
#   'genres': 'Adventure Family Fantasy',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'domestic_gross': 113929605,
#   'worldwide_gross': 491730089,
#   'opening_gross': 36948713,
#   'widest_release': 3820,
#   'release_date': datetime.datetime(2019, 10, 18, 0, 0)},
#  {'title': 'Glass',
#   'budget': 20000000,
#   'runtime': 129,
#   'rating': 'PG-13',
#   'genres': 'Drama Sci-Fi Thriller',
#   'distributor': 'Universal Pictures',
#   'domestic_gross': 111048468,
#   'worldwide_gross': 246999039,
#   'opening_gross': 40328920,
#   'widest_release': 3844,
#   'release_date': datetime.datetime(2019, 1, 18, 0, 0)},
#  {'title': 'Godzilla: King of the Monsters',
#   'budget': 170000000,
#   'runtime': 132,
#   'rating': 'PG-13',
#   'genres': 'Action Adventure Fantasy Sci-Fi',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 110500138,
#   'worldwide_gross': 386600138,
#   'opening_gross': 47776293,
#   'widest_release': 4108,
#   'release_date': datetime.datetime(2019, 5, 31, 0, 0)},
#  {'title': 'The Upside',
#   'budget': 37500000,
#   'runtime': 126,
#   'rating': 'PG-13',
#   'genres': 'Comedy Drama',
#   'distributor': 'STX Entertainment',
#   'domestic_gross': 108252517,
#   'worldwide_gross': 125852517,
#   'opening_gross': 20355000,
#   'widest_release': 3568,
#   'release_date': datetime.datetime(2019, 1, 11, 0, 0)},
#  {'title': 'Ford v Ferrari',
#   'budget': 97600000,
#   'runtime': 152,
#   'rating': 'PG-13',
#   'genres': 'Action Biography Drama Sport',
#   'distributor': 'Twentieth Century Fox',
#   'domestic_gross': 117624357,
#   'worldwide_gross': 225508210,
#   'opening_gross': 31474958,
#   'widest_release': 3746,
#   'release_date': datetime.datetime(2019, 11, 15, 0, 0)},
#  {'title': 'The Lego Movie 2: The Second Part',
#   'budget': 99000000,
#   'runtime': 107,
#   'rating': 'PG',
#   'genres': 'Action Adventure Animation Comedy Family Fantasy Musical',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 105806508,
#   'worldwide_gross': 192306508,
#   'opening_gross': 34115335,
#   'widest_release': 4303,
#   'release_date': datetime.datetime(2019, 2, 8, 0, 0)},
#  {'title': 'Hustlers',
#   'budget': 20000000,
#   'runtime': 110,
#   'rating': 'R',
#   'genres': 'Comedy Crime Drama',
#   'distributor': 'STX Entertainment',
#   'domestic_gross': 104963598,
#   'worldwide_gross': 157563598,
#   'opening_gross': 33181361,
#   'widest_release': 3525,
#   'release_date': datetime.datetime(2019, 9, 13, 0, 0)},
#  {'title': 'The Addams Family',
#   'budget': 24000000,
#   'runtime': 86,
#   'rating': 'PG',
#   'genres': 'Animation Comedy Family Fantasy Horror',
#   'distributor': 'United Artists Releasing',
#   'domestic_gross': 100044905,
#   'worldwide_gross': 203044905,
#   'opening_gross': 30300007,
#   'widest_release': 4107,
#   'release_date': datetime.datetime(2019, 10, 11, 0, 0)},
#  {'title': 'Downton Abbey',
#   'budget': 13000000,
#   'runtime': 122,
#   'rating': 'PG',
#   'genres': 'Drama Romance',
#   'distributor': 'Focus Features',
#   'domestic_gross': 96854135,
#   'worldwide_gross': 193820755,
#   'opening_gross': 31033665,
#   'widest_release': 3548,
#   'release_date': datetime.datetime(2019, 9, 20, 0, 0)},
#  {'title': 'Rocketman',
#   'budget': 40000000,
#   'runtime': 121,
#   'rating': 'R',
#   'genres': 'Biography Drama Music Musical',
#   'distributor': 'Paramount Pictures',
#   'domestic_gross': 96368160,
#   'worldwide_gross': 195179299,
#   'opening_gross': 25725722,
#   'widest_release': 3610,
#   'release_date': datetime.datetime(2019, 5, 31, 0, 0)},
#  {'title': 'Alita: Battle Angel',
#   'budget': 170000000,
#   'runtime': 122,
#   'rating': 'PG-13',
#   'genres': 'Action Adventure Sci-Fi Thriller',
#   'distributor': 'Twentieth Century Fox',
#   'domestic_gross': 85838210,
#   'worldwide_gross': 404980543,
#   'opening_gross': 28525613,
#   'widest_release': 3802,
#   'release_date': datetime.datetime(2019, 2, 14, 0, 0)},
#  {'title': 'Good Boys',
#   'budget': 20000000,
#   'runtime': 90,
#   'rating': 'R',
#   'genres': 'Adventure Comedy',
#   'distributor': 'Universal Pictures',
#   'domestic_gross': 83140306,
#   'worldwide_gross': 111037232,
#   'opening_gross': 21402605,
#   'widest_release': 3458,
#   'release_date': datetime.datetime(2019, 8, 16, 0, 0)},
#  {'title': 'Spider-Man: Into the Spider-Verse',
#   'budget': None,
#   'runtime': 117,
#   'rating': 'PG',
#   'genres': 'Action Adventure Animation Family Sci-Fi',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'domestic_gross': 190241310,
#   'worldwide_gross': 375540831,
#   'opening_gross': 35363376,
#   'widest_release': 3813,
#   'release_date': datetime.datetime(2018, 12, 14, 0, 0)},
#  {'title': 'Men in Black: International',
#   'budget': 110000000,
#   'runtime': 114,
#   'rating': 'PG-13',
#   'genres': 'Action Adventure Comedy Sci-Fi',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'domestic_gross': 80001807,
#   'worldwide_gross': 253890701,
#   'opening_gross': 30035838,
#   'widest_release': 4224,
#   'release_date': datetime.datetime(2019, 6, 14, 0, 0)},
#  {'title': 'Annabelle Comes Home',
#   'budget': 30000000,
#   'runtime': 106,
#   'rating': 'R',
#   'genres': 'Horror Mystery Thriller',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 74152591,
#   'worldwide_gross': 231252591,
#   'opening_gross': 20269723,
#   'widest_release': 3613,
#   'release_date': datetime.datetime(2019, 6, 26, 0, 0)},
#  {'title': 'Yesterday',
#   'budget': 26000000,
#   'runtime': 116,
#   'rating': 'PG-13',
#   'genres': 'Comedy Fantasy Music Romance',
#   'distributor': 'Universal Pictures',
#   'domestic_gross': 73286650,
#   'worldwide_gross': 153178480,
#   'opening_gross': 17010050,
#   'widest_release': 2755,
#   'release_date': datetime.datetime(2019, 6, 28, 0, 0)},
#  {'title': 'A Madea Family Funeral',
#   'budget': 20000000,
#   'runtime': 109,
#   'rating': 'PG-13',
#   'genres': 'Comedy',
#   'distributor': 'Lionsgate',
#   'domestic_gross': 73257045,
#   'worldwide_gross': 74747725,
#   'opening_gross': 27062332,
#   'widest_release': 2442,
#   'release_date': datetime.datetime(2019, 3, 1, 0, 0)},
#  {'title': 'Zombieland: Double Tap',
#   'budget': 42000000,
#   'runtime': 99,
#   'rating': 'R',
#   'genres': 'Action Comedy Horror',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'domestic_gross': 73123082,
#   'worldwide_gross': 122810399,
#   'opening_gross': 26803104,
#   'widest_release': 3468,
#   'release_date': datetime.datetime(2019, 10, 18, 0, 0)},
#  {'title': 'Angel Has Fallen',
#   'budget': 40000000,
#   'runtime': 121,
#   'rating': 'R',
#   'genres': 'Action Thriller',
#   'distributor': 'Lionsgate',
#   'domestic_gross': 69030436,
#   'worldwide_gross': 146661977,
#   'opening_gross': 21380987,
#   'widest_release': 3336,
#   'release_date': datetime.datetime(2019, 8, 23, 0, 0)},
#  {'title': 'Scary Stories to Tell in the Dark',
#   'budget': 25000000,
#   'runtime': 108,
#   'rating': 'PG-13',
#   'genres': 'Adventure Horror Mystery',
#   'distributor': 'Lionsgate',
#   'domestic_gross': 68947075,
#   'worldwide_gross': 104545505,
#   'opening_gross': 20915346,
#   'widest_release': 3135,
#   'release_date': datetime.datetime(2019, 8, 9, 0, 0)},
#  {'title': 'Mary Poppins Returns',
#   'budget': 130000000,
#   'runtime': 130,
#   'rating': 'PG',
#   'genres': 'Animation Comedy Family Fantasy Musical',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'domestic_gross': 171958438,
#   'worldwide_gross': 349537494,
#   'opening_gross': 23523121,
#   'widest_release': 4090,
#   'release_date': datetime.datetime(2018, 12, 19, 0, 0)},
#  {'title': 'X-Men: Dark Phoenix',
#   'budget': 200000000,
#   'runtime': 113,
#   'rating': 'PG-13',
#   'genres': 'Action Adventure Sci-Fi',
#   'distributor': 'Twentieth Century Fox',
#   'domestic_gross': 65845974,
#   'worldwide_gross': 252442974,
#   'opening_gross': 32828348,
#   'widest_release': 3721,
#   'release_date': datetime.datetime(2019, 6, 7, 0, 0)},
#  {'title': 'Terminator: Dark Fate',
#   'budget': 185000000,
#   'runtime': 128,
#   'rating': 'R',
#   'genres': 'Action Adventure Sci-Fi',
#   'distributor': 'Paramount Pictures',
#   'domestic_gross': 62253077,
#   'worldwide_gross': 261119292,
#   'opening_gross': 29033832,
#   'widest_release': 4086,
#   'release_date': datetime.datetime(2019, 11, 1, 0, 0)},
#  {'title': 'Abominable',
#   'budget': 75000000,
#   'runtime': 97,
#   'rating': 'PG',
#   'genres': 'Adventure Animation Comedy Family Fantasy',
#   'distributor': 'Universal Pictures',
#   'domestic_gross': 60716390,
#   'worldwide_gross': 179053956,
#   'opening_gross': 20612100,
#   'widest_release': 4248,
#   'release_date': datetime.datetime(2019, 9, 27, 0, 0)},
#  {'title': 'Dora and the Lost City of Gold',
#   'budget': 49000000,
#   'runtime': 102,
#   'rating': 'PG',
#   'genres': 'Adventure Comedy Family Mystery',
#   'distributor': 'Paramount Pictures',
#   'domestic_gross': 60477943,
#   'worldwide_gross': 119682635,
#   'opening_gross': 17431588,
#   'widest_release': 3735,
#   'release_date': datetime.datetime(2019, 8, 9, 0, 0)},
#  {'title': 'Escape Room',
#   'budget': 9000000,
#   'runtime': 99,
#   'rating': 'PG-13',
#   'genres': 'Action Adventure Horror Mystery Sci-Fi Thriller',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'domestic_gross': 57005601,
#   'worldwide_gross': 155712077,
#   'opening_gross': 18238172,
#   'widest_release': 2717,
#   'release_date': datetime.datetime(2019, 1, 4, 0, 0)},
#  {'title': 'A Beautiful Day in the Neighborhood',
#   'budget': 25000000,
#   'runtime': 109,
#   'rating': 'PG',
#   'genres': 'Biography Drama',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'domestic_gross': 61704055,
#   'worldwide_gross': 67760877,
#   'opening_gross': 13251238,
#   'widest_release': 3491,
#   'release_date': datetime.datetime(2019, 11, 22, 0, 0)},
#  {'title': 'Midway',
#   'budget': 100000000,
#   'runtime': 138,
#   'rating': 'PG-13',
#   'genres': 'Action Drama History War',
#   'distributor': 'Lionsgate',
#   'domestic_gross': 56846802,
#   'worldwide_gross': 127420861,
#   'opening_gross': 17897419,
#   'widest_release': 3242,
#   'release_date': datetime.datetime(2019, 11, 8, 0, 0)},
#  {'title': 'Bumblebee',
#   'budget': 135000000,
#   'runtime': 114,
#   'rating': 'PG-13',
#   'genres': 'Action Adventure Sci-Fi',
#   'distributor': 'Paramount Pictures',
#   'domestic_gross': 127195589,
#   'worldwide_gross': 467989645,
#   'opening_gross': 21654047,
#   'widest_release': 3597,
#   'release_date': datetime.datetime(2018, 12, 21, 0, 0)},
#  {'title': 'The Curse of la Llorona',
#   'budget': 9000000,
#   'runtime': 93,
#   'rating': 'R',
#   'genres': 'Horror Mystery Thriller',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 54733739,
#   'worldwide_gross': 123133739,
#   'opening_gross': 26347631,
#   'widest_release': 3372,
#   'release_date': datetime.datetime(2019, 4, 19, 0, 0)},
#  {'title': 'Pet Sematary',
#   'budget': 21000000,
#   'runtime': 101,
#   'rating': 'R',
#   'genres': 'Horror Mystery Thriller',
#   'distributor': 'Paramount Pictures',
#   'domestic_gross': 54724696,
#   'worldwide_gross': 113118226,
#   'opening_gross': 24502775,
#   'widest_release': 3585,
#   'release_date': datetime.datetime(2019, 4, 5, 0, 0)},
#  {'title': 'What Men Want',
#   'budget': 20000000,
#   'runtime': 117,
#   'rating': 'R',
#   'genres': 'Comedy Fantasy Romance',
#   'distributor': 'Paramount Pictures',
#   'domestic_gross': 54611903,
#   'worldwide_gross': 72216294,
#   'opening_gross': 18232087,
#   'widest_release': 2912,
#   'release_date': datetime.datetime(2019, 2, 8, 0, 0)},
#  {'title': 'Green Book',
#   'budget': 23000000,
#   'runtime': 130,
#   'rating': 'PG-13',
#   'genres': 'Biography Comedy Drama Music',
#   'distributor': 'Universal Pictures',
#   'domestic_gross': 85080171,
#   'worldwide_gross': 321752656,
#   'opening_gross': 320429,
#   'widest_release': 2648,
#   'release_date': datetime.datetime(2018, 11, 16, 0, 0)},
#  {'title': 'Ad Astra',
#   'budget': 90000000,
#   'runtime': 123,
#   'rating': 'PG-13',
#   'genres': 'Adventure Drama Mystery Sci-Fi Thriller',
#   'distributor': 'Twentieth Century Fox',
#   'domestic_gross': 50188370,
#   'worldwide_gross': 127461872,
#   'opening_gross': 19001398,
#   'widest_release': 3460,
#   'release_date': datetime.datetime(2019, 9, 20, 0, 0)},
#  {'title': "Isn't It Romantic",
#   'budget': 31000000,
#   'runtime': 89,
#   'rating': 'PG-13',
#   'genres': 'Comedy Fantasy Musical Romance',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 48791187,
#   'worldwide_gross': 48791187,
#   'opening_gross': 14247758,
#   'widest_release': 3444,
#   'release_date': datetime.datetime(2019, 2, 13, 0, 0)},
#  {'title': 'Gemini Man',
#   'budget': 138000000,
#   'runtime': 117,
#   'rating': 'PG-13',
#   'genres': 'Action Drama Sci-Fi Thriller',
#   'distributor': 'Paramount Pictures',
#   'domestic_gross': 48546770,
#   'worldwide_gross': 173469516,
#   'opening_gross': 20552372,
#   'widest_release': 3642,
#   'release_date': datetime.datetime(2019, 10, 11, 0, 0)},
#  {'title': 'Ma',
#   'budget': 5000000,
#   'runtime': 99,
#   'rating': 'R',
#   'genres': 'Horror Mystery Thriller',
#   'distributor': 'Universal Pictures',
#   'domestic_gross': 45896028,
#   'worldwide_gross': 61105672,
#   'opening_gross': 18099805,
#   'widest_release': 2816,
#   'release_date': datetime.datetime(2019, 5, 31, 0, 0)},
#  {'title': 'Five Feet Apart',
#   'budget': 7000000,
#   'runtime': 116,
#   'rating': 'PG-13',
#   'genres': 'Drama Romance',
#   'distributor': 'Lionsgate',
#   'domestic_gross': 45729221,
#   'worldwide_gross': 91522094,
#   'opening_gross': 13190286,
#   'widest_release': 2866,
#   'release_date': datetime.datetime(2019, 3, 15, 0, 0)},
#  {'title': 'Wonder Park',
#   'budget': 90000000,
#   'runtime': 85,
#   'rating': 'PG',
#   'genres': 'Adventure Animation Comedy Family Fantasy',
#   'distributor': 'Paramount Pictures',
#   'domestic_gross': 45216793,
#   'worldwide_gross': 119559110,
#   'opening_gross': 15853646,
#   'widest_release': 3838,
#   'release_date': datetime.datetime(2019, 3, 15, 0, 0)},
#  {'title': 'Rambo: Last Blood',
#   'budget': 50000000,
#   'runtime': 89,
#   'rating': 'R',
#   'genres': 'Action Thriller',
#   'distributor': 'Lionsgate',
#   'domestic_gross': 44819352,
#   'worldwide_gross': 91490353,
#   'opening_gross': 18872919,
#   'widest_release': 3618,
#   'release_date': datetime.datetime(2019, 9, 20, 0, 0)},
#  {'title': 'Playing with Fire',
#   'budget': 29900000,
#   'runtime': 96,
#   'rating': 'PG',
#   'genres': 'Comedy Family',
#   'distributor': 'Paramount Pictures',
#   'domestic_gross': 44451847,
#   'worldwide_gross': 69412425,
#   'opening_gross': 12723781,
#   'widest_release': 3185,
#   'release_date': datetime.datetime(2019, 11, 8, 0, 0)},
#  {'title': 'Harriet',
#   'budget': 17000000,
#   'runtime': 125,
#   'rating': 'PG-13',
#   'genres': 'Action Biography Drama History',
#   'distributor': 'Focus Features',
#   'domestic_gross': 43082155,
#   'worldwide_gross': 43347017,
#   'opening_gross': 11676720,
#   'widest_release': 2186,
#   'release_date': datetime.datetime(2019, 11, 1, 0, 0)},
#  {'title': "A Dog's Way Home",
#   'budget': 18000000,
#   'runtime': 96,
#   'rating': 'PG',
#   'genres': 'Adventure Drama Family',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'domestic_gross': 42004346,
#   'worldwide_gross': 80708134,
#   'opening_gross': 11251263,
#   'widest_release': 3090,
#   'release_date': datetime.datetime(2019, 1, 11, 0, 0)},
#  {'title': 'The Angry Birds Movie 2',
#   'budget': 65000000,
#   'runtime': 97,
#   'rating': 'PG',
#   'genres': 'Adventure Animation Comedy Family',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'domestic_gross': 41667116,
#   'worldwide_gross': 147792047,
#   'opening_gross': 10354073,
#   'widest_release': 3869,
#   'release_date': datetime.datetime(2019, 8, 13, 0, 0)},
#  {'title': 'Little',
#   'budget': 20000000,
#   'runtime': 109,
#   'rating': 'PG-13',
#   'genres': 'Comedy Fantasy Romance',
#   'distributor': 'Universal Pictures',
#   'domestic_gross': 40860481,
#   'worldwide_gross': 48987096,
#   'opening_gross': 15405455,
#   'widest_release': 2667,
#   'release_date': datetime.datetime(2019, 4, 12, 0, 0)},
#  {'title': 'Queen & Slim',
#   'budget': 18000000,
#   'runtime': 132,
#   'rating': 'R',
#   'genres': 'Crime Drama Romance',
#   'distributor': 'Universal Pictures',
#   'domestic_gross': 43808310,
#   'worldwide_gross': 47856414,
#   'opening_gross': 11890490,
#   'widest_release': 1715,
#   'release_date': datetime.datetime(2019, 11, 27, 0, 0)},
#  {'title': 'Breakthrough',
#   'budget': 14000000,
#   'runtime': 116,
#   'rating': 'PG',
#   'genres': 'Biography Drama',
#   'distributor': 'Twentieth Century Fox',
#   'domestic_gross': 40713082,
#   'worldwide_gross': 50444358,
#   'opening_gross': 11282333,
#   'widest_release': 2913,
#   'release_date': datetime.datetime(2019, 4, 17, 0, 0)},
#  {'title': 'The Mule',
#   'budget': 50000000,
#   'runtime': 116,
#   'rating': 'R',
#   'genres': 'Crime Drama Thriller',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 103804407,
#   'worldwide_gross': 174804407,
#   'opening_gross': 17509431,
#   'widest_release': 3329,
#   'release_date': datetime.datetime(2018, 12, 14, 0, 0)},
#  {'title': 'Crawl',
#   'budget': 13500000,
#   'runtime': 87,
#   'rating': 'R',
#   'genres': 'Action Horror Thriller',
#   'distributor': 'Paramount Pictures',
#   'domestic_gross': 39014193,
#   'worldwide_gross': 91542097,
#   'opening_gross': 12005210,
#   'widest_release': 3170,
#   'release_date': datetime.datetime(2019, 7, 12, 0, 0)},
#  {'title': 'Little Women',
#   'budget': 40000000,
#   'runtime': 135,
#   'rating': 'PG',
#   'genres': 'Drama Romance',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'domestic_gross': 108101214,
#   'worldwide_gross': 216601214,
#   'opening_gross': 16755310,
#   'widest_release': 3308,
#   'release_date': datetime.datetime(2019, 12, 25, 0, 0)},
#  {'title': 'The Intruder',
#   'budget': 8000000,
#   'runtime': 102,
#   'rating': 'PG-13',
#   'genres': 'Thriller',
#   'distributor': 'Screen Gems',
#   'domestic_gross': 35419122,
#   'worldwide_gross': 36599361,
#   'opening_gross': 10855054,
#   'widest_release': 2231,
#   'release_date': datetime.datetime(2019, 5, 3, 0, 0)},
#  {'title': 'The Hustle',
#   'budget': 21000000,
#   'runtime': 93,
#   'rating': 'PG-13',
#   'genres': 'Comedy Crime',
#   'distributor': 'United Artists Releasing',
#   'domestic_gross': 35417038,
#   'worldwide_gross': 95017038,
#   'opening_gross': 13007709,
#   'widest_release': 3077,
#   'release_date': datetime.datetime(2019, 5, 10, 0, 0)},
#  {'title': 'Last Christmas',
#   'budget': 25000000,
#   'runtime': 103,
#   'rating': 'PG-13',
#   'genres': 'Comedy Drama Fantasy Romance',
#   'distributor': 'Universal Pictures',
#   'domestic_gross': 35150750,
#   'worldwide_gross': 121550750,
#   'opening_gross': 11441055,
#   'widest_release': 3454,
#   'release_date': datetime.datetime(2019, 11, 8, 0, 0)},
#  {'title': 'Overcomer',
#   'budget': 5000000,
#   'runtime': 119,
#   'rating': 'PG',
#   'genres': 'Drama Family Sport',
#   'distributor': 'Affirm Films',
#   'domestic_gross': 34746945,
#   'worldwide_gross': 38026103,
#   'opening_gross': 8146533,
#   'widest_release': 2293,
#   'release_date': datetime.datetime(2019, 8, 23, 0, 0)},
#  {'title': 'Cold Pursuit',
#   'budget': 60000000,
#   'runtime': 119,
#   'rating': 'R',
#   'genres': 'Action Comedy Crime Drama Thriller',
#   'distributor': 'Lionsgate',
#   'domestic_gross': 32138862,
#   'worldwide_gross': 76419755,
#   'opening_gross': 11030233,
#   'widest_release': 2630,
#   'release_date': datetime.datetime(2019, 2, 8, 0, 0)},
#  {'title': 'Doctor Sleep',
#   'budget': 45000000,
#   'runtime': 152,
#   'rating': 'R',
#   'genres': 'Drama Fantasy Horror Thriller',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 31581712,
#   'worldwide_gross': 72381712,
#   'opening_gross': 14114124,
#   'widest_release': 3855,
#   'release_date': datetime.datetime(2019, 11, 8, 0, 0)},
#  {'title': 'Dragon Ball Super: Broly',
#   'budget': 8500000,
#   'runtime': 100,
#   'rating': 'PG',
#   'genres': 'Action Adventure Animation Family Fantasy Sci-Fi',
#   'distributor': 'FUNimation Entertainment',
#   'domestic_gross': 30712119,
#   'worldwide_gross': 115757940,
#   'opening_gross': 9816197,
#   'widest_release': 1267,
#   'release_date': datetime.datetime(2019, 1, 16, 0, 0)},
#  {'title': 'Long Shot',
#   'budget': 40000000,
#   'runtime': 125,
#   'rating': 'R',
#   'genres': 'Comedy Romance',
#   'distributor': 'Lionsgate',
#   'domestic_gross': 30316271,
#   'worldwide_gross': 53873809,
#   'opening_gross': 9740064,
#   'widest_release': 3230,
#   'release_date': datetime.datetime(2019, 5, 3, 0, 0)},
#  {'title': 'Spies in Disguise',
#   'budget': 100000000,
#   'runtime': 102,
#   'rating': 'PG',
#   'genres': 'Action Adventure Animation Comedy Family Sci-Fi',
#   'distributor': 'Twentieth Century Fox',
#   'domestic_gross': 66757013,
#   'worldwide_gross': 171616764,
#   'opening_gross': 13354798,
#   'widest_release': 3502,
#   'release_date': datetime.datetime(2019, 12, 25, 0, 0)},
#  {'title': "Child's Play",
#   'budget': 10000000,
#   'runtime': 90,
#   'rating': 'R',
#   'genres': 'Drama Horror Sci-Fi',
#   'distributor': 'United Artists Releasing',
#   'domestic_gross': 29208403,
#   'worldwide_gross': 44907074,
#   'opening_gross': 14094594,
#   'widest_release': 3007,
#   'release_date': datetime.datetime(2019, 6, 21, 0, 0)},
#  {'title': 'Ready or Not',
#   'budget': 6000000,
#   'runtime': 95,
#   'rating': 'R',
#   'genres': 'Action Comedy Horror Mystery Thriller',
#   'distributor': 'Fox Searchlight Pictures',
#   'domestic_gross': 28714231,
#   'worldwide_gross': 57615777,
#   'opening_gross': 8015590,
#   'widest_release': 2998,
#   'release_date': datetime.datetime(2019, 8, 21, 0, 0)},
#  {'title': 'Happy Death Day 2U',
#   'budget': 9000000,
#   'runtime': 100,
#   'rating': 'PG-13',
#   'genres': 'Comedy Horror Mystery Sci-Fi Thriller',
#   'distributor': 'Universal Pictures',
#   'domestic_gross': 28148130,
#   'worldwide_gross': 64600152,
#   'opening_gross': 9497665,
#   'widest_release': 3212,
#   'release_date': datetime.datetime(2019, 2, 13, 0, 0)},
#  {'title': 'Vice',
#   'budget': None,
#   'runtime': 132,
#   'rating': 'R',
#   'genres': 'Biography Comedy Drama',
#   'distributor': 'Annapurna Pictures',
#   'domestic_gross': 47836282,
#   'worldwide_gross': 76073488,
#   'opening_gross': 7768371,
#   'widest_release': 2534,
#   'release_date': datetime.datetime(2018, 12, 25, 0, 0)},
#  {'title': '21 Bridges',
#   'budget': 33000000,
#   'runtime': 99,
#   'rating': 'R',
#   'genres': 'Action Crime Thriller',
#   'distributor': 'STX Entertainment',
#   'domestic_gross': 28539757,
#   'worldwide_gross': 49939757,
#   'opening_gross': 9261268,
#   'widest_release': 2665,
#   'release_date': datetime.datetime(2019, 11, 22, 0, 0)},
#  {'title': 'Midsommar',
#   'budget': 9000000,
#   'runtime': 148,
#   'rating': 'R',
#   'genres': 'Drama Horror Mystery Thriller',
#   'distributor': 'A24',
#   'domestic_gross': 27426361,
#   'worldwide_gross': 47863365,
#   'opening_gross': 6560030,
#   'widest_release': 2707,
#   'release_date': datetime.datetime(2019, 7, 3, 0, 0)},
#  {'title': 'Bohemian Rhapsody',
#   'budget': 52000000,
#   'runtime': 134,
#   'rating': 'PG-13',
#   'genres': 'Biography Drama Music',
#   'distributor': 'Twentieth Century Fox',
#   'domestic_gross': 216428042,
#   'worldwide_gross': 903655259,
#   'opening_gross': 51061119,
#   'widest_release': 4000,
#   'release_date': datetime.datetime(2018, 11, 2, 0, 0)},
#  {'title': 'The Art of Racing in the Rain',
#   'budget': 18000000,
#   'runtime': 109,
#   'rating': 'PG',
#   'genres': 'Comedy Drama Romance Sport',
#   'distributor': 'Twentieth Century Fox',
#   'domestic_gross': 26395642,
#   'worldwide_gross': 33766787,
#   'opening_gross': 8137584,
#   'widest_release': 2765,
#   'release_date': datetime.datetime(2019, 8, 9, 0, 0)},
#  {'title': 'Countdown',
#   'budget': 6500000,
#   'runtime': 90,
#   'rating': 'PG-13',
#   'genres': 'Horror Thriller',
#   'distributor': 'STX Entertainment',
#   'domestic_gross': 25621766,
#   'worldwide_gross': 48021766,
#   'opening_gross': 8865082,
#   'widest_release': 2675,
#   'release_date': datetime.datetime(2019, 10, 25, 0, 0)},
#  {'title': 'Uncut Gems',
#   'budget': 19000000,
#   'runtime': 135,
#   'rating': 'R',
#   'genres': 'Crime Drama Thriller',
#   'distributor': 'A24',
#   'domestic_gross': 50023780,
#   'worldwide_gross': 50023780,
#   'opening_gross': 537242,
#   'widest_release': 2686,
#   'release_date': datetime.datetime(2019, 12, 13, 0, 0)},
#  {'title': 'Judy',
#   'budget': None,
#   'runtime': 118,
#   'rating': 'PG-13',
#   'genres': 'Biography Drama Romance',
#   'distributor': 'Roadside Attractions',
#   'domestic_gross': 24313888,
#   'worldwide_gross': 45701880,
#   'opening_gross': 2916548,
#   'widest_release': 1627,
#   'release_date': datetime.datetime(2019, 9, 27, 0, 0)},
#  {'title': 'Ralph Breaks the Internet',
#   'budget': 175000000,
#   'runtime': 112,
#   'rating': 'PG',
#   'genres': 'Adventure Animation Comedy Family Fantasy Sci-Fi',
#   'distributor': 'Walt Disney Studios Motion Pictures',
#   'domestic_gross': 201091711,
#   'worldwide_gross': 529323962,
#   'opening_gross': 56237634,
#   'widest_release': 4017,
#   'release_date': datetime.datetime(2018, 11, 21, 0, 0)},
#  {'title': 'Fighting with My Family',
#   'budget': 11000000,
#   'runtime': 108,
#   'rating': 'PG-13',
#   'genres': 'Biography Comedy Drama Sport',
#   'distributor': 'Metro-Goldwyn-Mayer (MGM)',
#   'domestic_gross': 22958886,
#   'worldwide_gross': 40811919,
#   'opening_gross': 138780,
#   'widest_release': 2855,
#   'release_date': datetime.datetime(2019, 2, 14, 0, 0)},
#  {'title': 'On the Basis of Sex',
#   'budget': None,
#   'runtime': None,
#   'rating': 'PG-13',
#   'genres': 'Biography Drama',
#   'distributor': 'Focus Features',
#   'domestic_gross': 24622687,
#   'worldwide_gross': 38673750,
#   'opening_gross': 686355,
#   'widest_release': 1957,
#   'release_date': datetime.datetime(2018, 12, 25, 0, 0)},
#  {'title': "A Dog's Journey",
#   'budget': 16000000,
#   'runtime': 109,
#   'rating': 'PG',
#   'genres': 'Adventure Comedy Drama Family Fantasy',
#   'distributor': 'Universal Pictures',
#   'domestic_gross': 22782371,
#   'worldwide_gross': 75741734,
#   'opening_gross': 8030085,
#   'widest_release': 3279,
#   'release_date': datetime.datetime(2019, 5, 17, 0, 0)},
#  {'title': 'Booksmart',
#   'budget': 6000000,
#   'runtime': 102,
#   'rating': 'R',
#   'genres': 'Comedy',
#   'distributor': 'United Artists Releasing',
#   'domestic_gross': 22680962,
#   'worldwide_gross': 24959607,
#   'opening_gross': 6933620,
#   'widest_release': 2518,
#   'release_date': datetime.datetime(2019, 5, 24, 0, 0)},
#  {'title': 'Parasite',
#   'budget': 11400000,
#   'runtime': 132,
#   'rating': 'R',
#   'genres': 'Comedy Drama Thriller',
#   'distributor': 'Neon',
#   'domestic_gross': 53369749,
#   'worldwide_gross': 258774734,
#   'opening_gross': 393216,
#   'widest_release': 2001,
#   'release_date': datetime.datetime(2019, 10, 11, 0, 0)},
#  {'title': 'Stuber',
#   'budget': 16000000,
#   'runtime': 93,
#   'rating': 'R',
#   'genres': 'Action Comedy Crime Thriller',
#   'distributor': 'Twentieth Century Fox',
#   'domestic_gross': 22370452,
#   'worldwide_gross': 32390945,
#   'opening_gross': 8225384,
#   'widest_release': 3050,
#   'release_date': datetime.datetime(2019, 7, 12, 0, 0)},
#  {'title': '47 Meters Down: Uncaged',
#   'budget': 12000000,
#   'runtime': 90,
#   'rating': 'PG-13',
#   'genres': 'Adventure Drama Horror Thriller',
#   'distributor': 'Entertainment Studios Motion Pictures',
#   'domestic_gross': 22260900,
#   'worldwide_gross': 47582563,
#   'opening_gross': 8427265,
#   'widest_release': 2883,
#   'release_date': datetime.datetime(2019, 8, 16, 0, 0)},
#  {'title': 'Black and Blue',
#   'budget': 12000000,
#   'runtime': 108,
#   'rating': 'R',
#   'genres': 'Action Crime Thriller',
#   'distributor': 'Screen Gems',
#   'domestic_gross': 22055313,
#   'worldwide_gross': 22741061,
#   'opening_gross': 8376846,
#   'widest_release': 2062,
#   'release_date': datetime.datetime(2019, 10, 25, 0, 0)},
#  {'title': 'Hellboy',
#   'budget': 50000000,
#   'runtime': None,
#   'rating': 'R',
#   'genres': 'Action Adventure Fantasy Horror Sci-Fi',
#   'distributor': 'Lionsgate',
#   'domestic_gross': 21903748,
#   'worldwide_gross': 55064690,
#   'opening_gross': 12045147,
#   'widest_release': 3303,
#   'release_date': datetime.datetime(2019, 4, 12, 0, 0)},
#  {'title': 'Shaft',
#   'budget': 35000000,
#   'runtime': 111,
#   'rating': 'R',
#   'genres': 'Action Comedy Crime',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 21360215,
#   'worldwide_gross': 21360215,
#   'opening_gross': 8901419,
#   'widest_release': 2952,
#   'release_date': datetime.datetime(2019, 6, 14, 0, 0)},
#  {'title': 'Jojo Rabbit',
#   'budget': 14000000,
#   'runtime': 108,
#   'rating': 'PG-13',
#   'genres': 'Comedy Drama War',
#   'distributor': 'Fox Searchlight Pictures',
#   'domestic_gross': 33370906,
#   'worldwide_gross': 90335025,
#   'opening_gross': 349555,
#   'widest_release': 1173,
#   'release_date': datetime.datetime(2019, 10, 18, 0, 0)},
#  {'title': 'The Peanut Butter Falcon',
#   'budget': 6200000,
#   'runtime': 97,
#   'rating': 'PG-13',
#   'genres': 'Adventure Comedy Drama',
#   'distributor': 'Roadside Attractions',
#   'domestic_gross': 20457151,
#   'worldwide_gross': 23743627,
#   'opening_gross': 204793,
#   'widest_release': 1490,
#   'release_date': datetime.datetime(2019, 8, 9, 0, 0)},
#  {'title': 'UglyDolls',
#   'budget': None,
#   'runtime': 87,
#   'rating': 'PG',
#   'genres': 'Adventure Animation Comedy Family Fantasy Musical',
#   'distributor': 'STX Entertainment',
#   'domestic_gross': 20150241,
#   'worldwide_gross': 32450241,
#   'opening_gross': 8603407,
#   'widest_release': 3652,
#   'release_date': datetime.datetime(2019, 5, 3, 0, 0)},
#  {'title': 'Cats',
#   'budget': 95000000,
#   'runtime': 110,
#   'rating': 'PG',
#   'genres': 'Comedy Drama Family Fantasy Musical',
#   'distributor': 'Universal Pictures',
#   'domestic_gross': 27166770,
#   'worldwide_gross': 73833531,
#   'opening_gross': 6619870,
#   'widest_release': 3380,
#   'release_date': datetime.datetime(2019, 12, 20, 0, 0)},
#  {'title': 'Unplanned',
#   'budget': 6000000,
#   'runtime': 109,
#   'rating': 'R',
#   'genres': 'Biography Drama',
#   'distributor': 'Pure Flix Entertainment',
#   'domestic_gross': 19005109,
#   'worldwide_gross': 21349929,
#   'opening_gross': 6382298,
#   'widest_release': 1516,
#   'release_date': datetime.datetime(2019, 3, 29, 0, 0)},
#  {'title': 'The Favourite',
#   'budget': None,
#   'runtime': 119,
#   'rating': 'R',
#   'genres': 'Biography Comedy Drama History',
#   'distributor': 'Fox Searchlight Pictures',
#   'domestic_gross': 34366783,
#   'worldwide_gross': 95918706,
#   'opening_gross': 422410,
#   'widest_release': 1554,
#   'release_date': datetime.datetime(2018, 11, 23, 0, 0)},
#  {'title': 'Bombshell',
#   'budget': 32000000,
#   'runtime': 109,
#   'rating': 'R',
#   'genres': 'Biography Drama',
#   'distributor': 'Lionsgate',
#   'domestic_gross': 31762808,
#   'worldwide_gross': 61404394,
#   'opening_gross': 319157,
#   'widest_release': 1721,
#   'release_date': datetime.datetime(2019, 12, 13, 0, 0)},
#  {'title': 'Richard Jewell',
#   'budget': 45000000,
#   'runtime': 131,
#   'rating': 'R',
#   'genres': 'Biography Crime Drama',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 22345542,
#   'worldwide_gross': 43745542,
#   'opening_gross': 4705265,
#   'widest_release': 2502,
#   'release_date': datetime.datetime(2019, 12, 13, 0, 0)},
#  {'title': "Charlie's Angels",
#   'budget': 48000000,
#   'runtime': 118,
#   'rating': 'PG-13',
#   'genres': 'Action Adventure Comedy',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'domestic_gross': 17803077,
#   'worldwide_gross': 73279888,
#   'opening_gross': 8351109,
#   'widest_release': 3452,
#   'release_date': datetime.datetime(2019, 11, 15, 0, 0)},
#  {'title': 'The Farewell',
#   'budget': None,
#   'runtime': 100,
#   'rating': 'PG',
#   'genres': 'Comedy Drama',
#   'distributor': 'A24',
#   'domestic_gross': 17695781,
#   'worldwide_gross': 23076657,
#   'opening_gross': 355662,
#   'widest_release': 891,
#   'release_date': datetime.datetime(2019, 7, 12, 0, 0)},
#  {'title': 'Brightburn',
#   'budget': 6000000,
#   'runtime': 90,
#   'rating': 'R',
#   'genres': 'Drama Horror Mystery Sci-Fi',
#   'distributor': 'Screen Gems',
#   'domestic_gross': 17300439,
#   'worldwide_gross': 32893421,
#   'opening_gross': 7845658,
#   'widest_release': 2607,
#   'release_date': datetime.datetime(2019, 5, 24, 0, 0)},
#  {'title': 'The Good Liar',
#   'budget': 10000000,
#   'runtime': 109,
#   'rating': 'R',
#   'genres': 'Crime Drama Mystery Thriller',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 17156058,
#   'worldwide_gross': 33856058,
#   'opening_gross': 5605051,
#   'widest_release': 2454,
#   'release_date': datetime.datetime(2019, 11, 15, 0, 0)},
#  {'title': 'The Kid Who Would Be King',
#   'budget': None,
#   'runtime': None,
#   'rating': 'PG',
#   'genres': 'Action Adventure Family Fantasy',
#   'distributor': 'Twentieth Century Fox',
#   'domestic_gross': 16790790,
#   'worldwide_gross': 32140970,
#   'opening_gross': 7173887,
#   'widest_release': 3528,
#   'release_date': datetime.datetime(2019, 1, 25, 0, 0)},
#  {'title': 'Missing Link',
#   'budget': None,
#   'runtime': 93,
#   'rating': 'PG',
#   'genres': 'Adventure Animation Comedy Family Fantasy',
#   'distributor': 'United Artists Releasing',
#   'domestic_gross': 16649539,
#   'worldwide_gross': 26565710,
#   'opening_gross': 5944950,
#   'widest_release': 3437,
#   'release_date': datetime.datetime(2019, 4, 12, 0, 0)},
#  {'title': 'Second Act',
#   'budget': 16000000,
#   'runtime': 103,
#   'rating': 'PG-13',
#   'genres': 'Comedy Drama Romance',
#   'distributor': 'STX Entertainment',
#   'domestic_gross': 39282227,
#   'worldwide_gross': 72282227,
#   'opening_gross': 6489983,
#   'widest_release': 2607,
#   'release_date': datetime.datetime(2018, 12, 21, 0, 0)},
#  {'title': 'Late Night',
#   'budget': None,
#   'runtime': 102,
#   'rating': 'R',
#   'genres': 'Comedy Drama',
#   'distributor': 'Amazon Studios',
#   'domestic_gross': 15499454,
#   'worldwide_gross': 22386555,
#   'opening_gross': 246305,
#   'widest_release': 2220,
#   'release_date': datetime.datetime(2019, 6, 7, 0, 0)},
#  {'title': 'Miss Bala',
#   'budget': 15000000,
#   'runtime': 104,
#   'rating': 'PG-13',
#   'genres': 'Action Crime Drama Thriller',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'domestic_gross': 15006824,
#   'worldwide_gross': 15383580,
#   'opening_gross': 6864744,
#   'widest_release': 2203,
#   'release_date': datetime.datetime(2019, 2, 1, 0, 0)},
#  {'title': 'The Prodigy',
#   'budget': 6000000,
#   'runtime': 92,
#   'rating': 'R',
#   'genres': 'Fantasy Horror Mystery Thriller',
#   'distributor': 'Orion Pictures',
#   'domestic_gross': 14856291,
#   'worldwide_gross': 21150265,
#   'opening_gross': 5853061,
#   'widest_release': 2530,
#   'release_date': datetime.datetime(2019, 2, 8, 0, 0)},
#  {'title': 'A Star Is Born',
#   'budget': 36000000,
#   'runtime': 136,
#   'rating': 'R',
#   'genres': 'Drama Music Romance',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 215288866,
#   'worldwide_gross': 436188866,
#   'opening_gross': 42908051,
#   'widest_release': 3904,
#   'release_date': datetime.datetime(2018, 10, 5, 0, 0)},
#  {'title': 'Poms',
#   'budget': None,
#   'runtime': 90,
#   'rating': 'PG-13',
#   'genres': 'Comedy Drama Sport',
#   'distributor': 'STX Entertainment',
#   'domestic_gross': 13631124,
#   'worldwide_gross': 16418218,
#   'opening_gross': 5361937,
#   'widest_release': 2750,
#   'release_date': datetime.datetime(2019, 5, 10, 0, 0)},
#  {'title': 'If Beale Street Could Talk',
#   'budget': None,
#   'runtime': 119,
#   'rating': 'R',
#   'genres': 'Drama Romance',
#   'distributor': 'Annapurna Pictures',
#   'domestic_gross': 14915773,
#   'worldwide_gross': 20596567,
#   'opening_gross': 224476,
#   'widest_release': 1018,
#   'release_date': datetime.datetime(2018, 12, 14, 0, 0)},
#  {'title': 'They Shall Not Grow Old',
#   'budget': None,
#   'runtime': 99,
#   'rating': 'R',
#   'genres': 'Documentary History War',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 17956913,
#   'worldwide_gross': 20502132,
#   'opening_gross': None,
#   'widest_release': 1335,
#   'release_date': datetime.datetime(2018, 12, 17, 0, 0)},
#  {'title': 'The Kitchen',
#   'budget': 38000000,
#   'runtime': 102,
#   'rating': 'R',
#   'genres': 'Action Crime Drama',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 12180032,
#   'worldwide_gross': 15980032,
#   'opening_gross': 5527410,
#   'widest_release': 2745,
#   'release_date': datetime.datetime(2019, 8, 9, 0, 0)},
#  {'title': 'After',
#   'budget': 14000000,
#   'runtime': 105,
#   'rating': 'PG-13',
#   'genres': 'Drama Romance',
#   'distributor': 'Aviron Pictures',
#   'domestic_gross': 12138565,
#   'worldwide_gross': 69756455,
#   'opening_gross': 6002349,
#   'widest_release': 2138,
#   'release_date': datetime.datetime(2019, 4, 12, 0, 0)},
#  {'title': 'Blinded by the Light',
#   'budget': None,
#   'runtime': 118,
#   'rating': 'PG-13',
#   'genres': 'Comedy Drama Music',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 11901145,
#   'worldwide_gross': 18096691,
#   'opening_gross': 4333305,
#   'widest_release': 2307,
#   'release_date': datetime.datetime(2019, 8, 16, 0, 0)},
#  {'title': 'The Lighthouse',
#   'budget': None,
#   'runtime': 109,
#   'rating': 'R',
#   'genres': 'Drama Fantasy Horror Mystery',
#   'distributor': 'A24',
#   'domestic_gross': 10867104,
#   'worldwide_gross': 18123239,
#   'opening_gross': 427797,
#   'widest_release': 978,
#   'release_date': datetime.datetime(2019, 10, 18, 0, 0)},
#  {'title': 'Dark Waters',
#   'budget': None,
#   'runtime': 126,
#   'rating': 'PG-13',
#   'genres': 'Biography Drama History Thriller',
#   'distributor': 'Focus Features',
#   'domestic_gross': 11136084,
#   'worldwide_gross': 23108017,
#   'opening_gross': 102606,
#   'widest_release': 2112,
#   'release_date': datetime.datetime(2019, 11, 22, 0, 0)},
#  {'title': 'Greta',
#   'budget': None,
#   'runtime': 98,
#   'rating': 'R',
#   'genres': 'Drama Mystery Thriller',
#   'distributor': 'Focus Features',
#   'domestic_gross': 10532219,
#   'worldwide_gross': 18653107,
#   'opening_gross': 4481910,
#   'widest_release': 2417,
#   'release_date': datetime.datetime(2019, 3, 1, 0, 0)},
#  {'title': 'The Best of Enemies',
#   'budget': 10000000,
#   'runtime': 133,
#   'rating': 'PG-13',
#   'genres': 'Biography Drama History',
#   'distributor': 'STX Entertainment',
#   'domestic_gross': 10205616,
#   'worldwide_gross': 10209813,
#   'opening_gross': 4446190,
#   'widest_release': 1705,
#   'release_date': datetime.datetime(2019, 4, 5, 0, 0)},
#  {'title': 'Black Christmas',
#   'budget': 5000000,
#   'runtime': 92,
#   'rating': 'PG-13',
#   'genres': 'Horror Mystery Thriller',
#   'distributor': 'Universal Pictures',
#   'domestic_gross': 10429730,
#   'worldwide_gross': 18529730,
#   'opening_gross': 4240245,
#   'widest_release': 2625,
#   'release_date': datetime.datetime(2019, 12, 13, 0, 0)},
#  {'title': 'Hotel Mumbai',
#   'budget': None,
#   'runtime': 123,
#   'rating': 'R',
#   'genres': 'Action Drama History Thriller',
#   'distributor': 'Bleecker Street Media',
#   'domestic_gross': 9651611,
#   'worldwide_gross': 21314816,
#   'opening_gross': 88065,
#   'widest_release': 930,
#   'release_date': datetime.datetime(2019, 3, 22, 0, 0)},
#  {'title': 'Holmes & Watson',
#   'budget': 42000000,
#   'runtime': 90,
#   'rating': 'PG-13',
#   'genres': 'Comedy Crime Mystery',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'domestic_gross': 30573626,
#   'worldwide_gross': 40466970,
#   'opening_gross': 7411522,
#   'widest_release': 2780,
#   'release_date': datetime.datetime(2018, 12, 25, 0, 0)},
#  {'title': 'Motherless Brooklyn',
#   'budget': 26000000,
#   'runtime': 144,
#   'rating': 'R',
#   'genres': 'Crime Drama Mystery',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 9277736,
#   'worldwide_gross': 18477736,
#   'opening_gross': 3500454,
#   'widest_release': 1342,
#   'release_date': datetime.datetime(2019, 11, 1, 0, 0)},
#  {'title': 'No Manches Frida 2',
#   'budget': None,
#   'runtime': 102,
#   'rating': 'R',
#   'genres': 'Comedy',
#   'distributor': 'Pantelion Films',
#   'domestic_gross': 9270920,
#   'worldwide_gross': 26493648,
#   'opening_gross': 3831401,
#   'widest_release': 472,
#   'release_date': datetime.datetime(2019, 3, 15, 0, 0)},
#  {'title': "Where'd You Go, Bernadette",
#   'budget': None,
#   'runtime': 109,
#   'rating': 'PG-13',
#   'genres': 'Comedy Drama',
#   'distributor': 'United Artists Releasing',
#   'domestic_gross': 9198356,
#   'worldwide_gross': 11025353,
#   'opening_gross': 3462308,
#   'widest_release': 2404,
#   'release_date': datetime.datetime(2019, 8, 16, 0, 0)},
#  {'title': 'Apollo 11',
#   'budget': None,
#   'runtime': 93,
#   'rating': 'G',
#   'genres': 'Documentary History',
#   'distributor': 'Neon',
#   'domestic_gross': 9039891,
#   'worldwide_gross': 15342353,
#   'opening_gross': 1607040,
#   'widest_release': 588,
#   'release_date': datetime.datetime(2019, 3, 1, 0, 0)},
#  {'title': 'Serenity',
#   'budget': None,
#   'runtime': 106,
#   'rating': 'R',
#   'genres': 'Drama Mystery Thriller',
#   'distributor': 'Aviron Pictures',
#   'domestic_gross': 8547045,
#   'worldwide_gross': 14454622,
#   'opening_gross': 4415403,
#   'widest_release': 2561,
#   'release_date': datetime.datetime(2019, 1, 25, 0, 0)},
#  {'title': 'Anna',
# ...
#   'runtime': 107,
#   'rating': 'R',
#   'genres': 'Comedy Drama',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 7002261,
#   'worldwide_gross': 8527658,
#   'opening_gross': 3238433,
#   'widest_release': 2202,
#   'release_date': datetime.datetime(2015, 10, 30, 0, 0)},
#  {'title': 'Inherent Vice',
#   'budget': None,
#   'runtime': 148,
#   'rating': 'R',
#   'genres': 'Comedy Crime Drama Mystery Romance',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 8110975,
#   'worldwide_gross': 14710975,
#   'opening_gross': 328184,
#   'widest_release': 653,
#   'release_date': datetime.datetime(2014, 12, 12, 0, 0)},
#  {'title': 'Grandma',
#   'budget': 600000,
#   'runtime': 79,
#   'rating': 'R',
#   'genres': 'Comedy Drama',
#   'distributor': 'Sony Pictures Classics',
#   'domestic_gross': 6980524,
#   'worldwide_gross': 7205073,
#   'opening_gross': 115540,
#   'widest_release': 1061,
#   'release_date': datetime.datetime(2015, 8, 21, 0, 0)},
#  {'title': 'Trumbo',
#   'budget': None,
#   'runtime': 124,
#   'rating': 'R',
#   'genres': 'Biography Crime Drama',
#   'distributor': 'Bleecker Street Media',
#   'domestic_gross': 7857741,
#   'worldwide_gross': 11430025,
#   'opening_gross': 74177,
#   'widest_release': 660,
#   'release_date': datetime.datetime(2015, 11, 6, 0, 0)},
#  {'title': 'Me and Earl and the Dying Girl',
#   'budget': 8000000,
#   'runtime': 105,
#   'rating': 'PG-13',
#   'genres': 'Comedy Drama',
#   'distributor': 'Fox Searchlight Pictures',
#   'domestic_gross': 6758416,
#   'worldwide_gross': 9074749,
#   'opening_gross': 196496,
#   'widest_release': 870,
#   'release_date': datetime.datetime(2015, 6, 12, 0, 0)},
#  {'title': 'Little Boy',
#   'budget': None,
#   'runtime': 106,
#   'rating': 'PG-13',
#   'genres': 'Drama History War',
#   'distributor': 'Open Road Films (II)',
#   'domestic_gross': 6485961,
#   'worldwide_gross': 17572289,
#   'opening_gross': 2750356,
#   'widest_release': 1045,
#   'release_date': datetime.datetime(2015, 4, 24, 0, 0)},
#  {'title': 'The Loft',
#   'budget': None,
#   'runtime': 108,
#   'rating': 'R',
#   'genres': 'Mystery Romance Thriller',
#   'distributor': 'Open Road Films (II)',
#   'domestic_gross': 6002684,
#   'worldwide_gross': 11016443,
#   'opening_gross': 2747342,
#   'widest_release': 1841,
#   'release_date': datetime.datetime(2015, 1, 30, 0, 0)},
#  {'title': 'Victor Frankenstein',
#   'budget': None,
#   'runtime': 110,
#   'rating': 'PG-13',
#   'genres': 'Drama Horror Sci-Fi Thriller',
#   'distributor': 'Twentieth Century Fox',
#   'domestic_gross': 5775076,
#   'worldwide_gross': 34227298,
#   'opening_gross': 2469341,
#   'widest_release': 2797,
#   'release_date': datetime.datetime(2015, 11, 25, 0, 0)},
#  {'title': 'A Most Violent Year',
#   'budget': 20000000,
#   'runtime': 125,
#   'rating': 'R',
#   'genres': 'Action Crime Drama Thriller',
#   'distributor': 'A24',
#   'domestic_gross': 5749134,
#   'worldwide_gross': 12007070,
#   'opening_gross': 172788,
#   'widest_release': 818,
#   'release_date': datetime.datetime(2014, 12, 31, 0, 0)},
#  {'title': 'Danny Collins',
#   'budget': 10000000,
#   'runtime': 106,
#   'rating': 'R',
#   'genres': 'Biography Comedy Drama Music',
#   'distributor': 'Bleecker Street Media',
#   'domestic_gross': 5637066,
#   'worldwide_gross': 10835752,
#   'opening_gross': 72459,
#   'widest_release': 739,
#   'release_date': datetime.datetime(2015, 3, 20, 0, 0)},
#  {'title': 'Foxcatcher',
#   'budget': None,
#   'runtime': 134,
#   'rating': 'R',
#   'genres': 'Biography Drama History Sport',
#   'distributor': 'Sony Pictures Classics',
#   'domestic_gross': 12096300,
#   'worldwide_gross': 19206513,
#   'opening_gross': 270877,
#   'widest_release': 759,
#   'release_date': datetime.datetime(2014, 11, 14, 0, 0)},
#  {'title': 'Bajirao Mastani',
#   'budget': None,
#   'runtime': 158,
#   'rating': None,
#   'genres': 'Action Drama History Romance War',
#   'distributor': 'Eros International',
#   'domestic_gross': 6557047,
#   'worldwide_gross': 11350917,
#   'opening_gross': 1744975,
#   'widest_release': 304,
#   'release_date': datetime.datetime(2015, 12, 18, 0, 0)},
#  {'title': 'Room',
#   'budget': None,
#   'runtime': 118,
#   'rating': 'R',
#   'genres': 'Drama Thriller',
#   'distributor': 'A24',
#   'domestic_gross': 14677654,
#   'worldwide_gross': 35401758,
#   'opening_gross': 118298,
#   'widest_release': 862,
#   'release_date': datetime.datetime(2015, 10, 16, 0, 0)},
#  {'title': '90 Minutes in Heaven',
#   'budget': 5000000,
#   'runtime': 121,
#   'rating': 'PG-13',
#   'genres': 'Drama',
#   'distributor': 'The Samuel Goldwyn Company',
#   'domestic_gross': 4842699,
#   'worldwide_gross': 4842699,
#   'opening_gross': 2035273,
#   'widest_release': 899,
#   'release_date': datetime.datetime(2015, 9, 11, 0, 0)},
#  {'title': 'True Story',
#   'budget': None,
#   'runtime': 99,
#   'rating': 'R',
#   'genres': 'Biography Crime Drama History Mystery',
#   'distributor': 'Fox Searchlight Pictures',
#   'domestic_gross': 4719695,
#   'worldwide_gross': 5261595,
#   'opening_gross': 1950214,
#   'widest_release': 856,
#   'release_date': datetime.datetime(2015, 4, 17, 0, 0)},
#  {'title': 'Suffragette',
#   'budget': None,
#   'runtime': 106,
#   'rating': 'PG-13',
#   'genres': 'Drama History',
#   'distributor': 'Focus Features',
#   'domestic_gross': 4702420,
#   'worldwide_gross': 31972096,
#   'opening_gross': 76244,
#   'widest_release': 517,
#   'release_date': datetime.datetime(2015, 10, 23, 0, 0)},
#  {'title': 'Top Five',
#   'budget': None,
#   'runtime': 102,
#   'rating': 'R',
#   'genres': 'Comedy Romance',
#   'distributor': 'Paramount Pictures',
#   'domestic_gross': 25317471,
#   'worldwide_gross': 26117471,
#   'opening_gross': 6896593,
#   'widest_release': 1426,
#   'release_date': datetime.datetime(2014, 12, 12, 0, 0)},
#  {'title': 'Baahubali: The Beginning',
#   'budget': None,
#   'runtime': 159,
#   'rating': None,
#   'genres': 'Action Drama',
#   'distributor': 'Blue Sky Cinema',
#   'domestic_gross': 6738000,
#   'worldwide_gross': 6787855,
#   'opening_gross': 3575000,
#   'widest_release': 236,
#   'release_date': datetime.datetime(2015, 7, 9, 0, 0)},
#  {'title': 'The Danish Girl',
#   'budget': None,
#   'runtime': 119,
#   'rating': 'R',
#   'genres': 'Biography Drama Romance',
#   'distributor': 'Focus Features',
#   'domestic_gross': 11114018,
#   'worldwide_gross': 64191523,
#   'opening_gross': 187318,
#   'widest_release': 794,
#   'release_date': datetime.datetime(2015, 11, 27, 0, 0)},
#  {'title': 'Hubble 3D',
#   'budget': None,
#   'runtime': None,
#   'rating': None,
#   'genres': 'Documentary',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 52522904,
#   'worldwide_gross': 74249729,
#   'opening_gross': 413477,
#   'widest_release': 151,
#   'release_date': datetime.datetime(2010, 3, 19, 0, 0)},
#  {'title': 'Dilwale',
#   'budget': None,
#   'runtime': 158,
#   'rating': None,
#   'genres': 'Action Comedy Drama Romance',
#   'distributor': 'UTV Motion Pictures',
#   'domestic_gross': 4871263,
#   'worldwide_gross': 31994323,
#   'opening_gross': 1920402,
#   'widest_release': 268,
#   'release_date': datetime.datetime(2015, 12, 17, 0, 0)},
#  {'title': 'Prem Ratan Dhan Payo',
#   'budget': None,
#   'runtime': 164,
#   'rating': None,
#   'genres': 'Action Drama Musical Romance',
#   'distributor': 'FIP',
#   'domestic_gross': 4364639,
#   'worldwide_gross': 52715771,
#   'opening_gross': 2425585,
#   'widest_release': 287,
#   'release_date': datetime.datetime(2015, 11, 12, 0, 0)},
#  {'title': 'The Water Diviner',
#   'budget': 22500000,
#   'runtime': 111,
#   'rating': 'R',
#   'genres': 'Drama History War',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 4196641,
#   'worldwide_gross': 38176317,
#   'opening_gross': 1220335,
#   'widest_release': 385,
#   'release_date': datetime.datetime(2015, 4, 24, 0, 0)},
#  {'title': 'Irrational Man',
#   'budget': None,
#   'runtime': 95,
#   'rating': 'R',
#   'genres': 'Comedy Drama Romance',
#   'distributor': 'Sony Pictures Classics',
#   'domestic_gross': 4030360,
#   'worldwide_gross': 27391084,
#   'opening_gross': 175312,
#   'widest_release': 925,
#   'release_date': datetime.datetime(2015, 7, 17, 0, 0)},
#  {'title': 'Carol',
#   'budget': None,
#   'runtime': 118,
#   'rating': 'R',
#   'genres': 'Drama Romance',
#   'distributor': 'The Weinstein Company',
#   'domestic_gross': 12711491,
#   'worldwide_gross': 40272135,
#   'opening_gross': 253510,
#   'widest_release': 790,
#   'release_date': datetime.datetime(2015, 11, 20, 0, 0)},
#  {'title': 'Scouts Guide to the Zombie Apocalypse',
#   'budget': 15000000,
#   'runtime': 93,
#   'rating': 'R',
#   'genres': 'Action Comedy Horror',
#   'distributor': 'Paramount Pictures',
#   'domestic_gross': 3703046,
#   'worldwide_gross': 16137046,
#   'opening_gross': 1841007,
#   'widest_release': 1509,
#   'release_date': datetime.datetime(2015, 10, 30, 0, 0)},
#  {'title': 'A la mala',
#   'budget': None,
#   'runtime': 99,
#   'rating': 'PG-13',
#   'genres': 'Comedy',
#   'distributor': 'Lionsgate',
#   'domestic_gross': 3629842,
#   'worldwide_gross': 3646627,
#   'opening_gross': 1402118,
#   'widest_release': 384,
#   'release_date': datetime.datetime(2015, 2, 27, 0, 0)},
#  {'title': 'Spare Parts',
#   'budget': None,
#   'runtime': 114,
#   'rating': 'PG-13',
#   'genres': 'Biography Drama History',
#   'distributor': 'Lionsgate',
#   'domestic_gross': 3618912,
#   'worldwide_gross': 3701281,
#   'opening_gross': 1335768,
#   'widest_release': 440,
#   'release_date': datetime.datetime(2015, 1, 16, 0, 0)},
#  {'title': 'We Are Your Friends',
#   'budget': None,
#   'runtime': 96,
#   'rating': 'R',
#   'genres': 'Drama Music Romance',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 3591417,
#   'worldwide_gross': 11122090,
#   'opening_gross': 1767308,
#   'widest_release': 2333,
#   'release_date': datetime.datetime(2015, 8, 28, 0, 0)},
#  {'title': 'What We Do in the Shadows',
#   'budget': None,
#   'runtime': 86,
#   'rating': 'R',
#   'genres': 'Comedy Horror',
#   'distributor': 'Unison/Paladin',
#   'domestic_gross': 3469224,
#   'worldwide_gross': 7251226,
#   'opening_gross': 88940,
#   'widest_release': 154,
#   'release_date': datetime.datetime(2015, 2, 13, 0, 0)},
#  {'title': 'Learning to Drive',
#   'budget': None,
#   'runtime': 90,
#   'rating': 'R',
#   'genres': 'Comedy Drama Romance',
#   'distributor': 'Broad Green Pictures',
#   'domestic_gross': 3447633,
#   'worldwide_gross': 5967516,
#   'opening_gross': 66015,
#   'widest_release': 339,
#   'release_date': datetime.datetime(2015, 8, 21, 0, 0)},
#  {'title': 'Mr. Turner',
#   'budget': None,
#   'runtime': 150,
#   'rating': 'R',
#   'genres': 'Biography Drama History',
#   'distributor': 'Sony Pictures Classics',
#   'domestic_gross': 3958500,
#   'worldwide_gross': 22179785,
#   'opening_gross': 109000,
#   'widest_release': 120,
#   'release_date': datetime.datetime(2014, 12, 19, 0, 0)},
#  {'title': 'Phoenix',
#   'budget': None,
#   'runtime': 98,
#   'rating': 'PG-13',
#   'genres': 'Drama History Music Romance',
#   'distributor': 'IFC Films',
#   'domestic_gross': 3184472,
#   'worldwide_gross': 5793245,
#   'opening_gross': 30296,
#   'widest_release': 197,
#   'release_date': datetime.datetime(2015, 7, 24, 0, 0)},
#  {'title': 'Dil Dhadakne Do',
#   'budget': None,
#   'runtime': 170,
#   'rating': None,
#   'genres': 'Comedy Drama Romance',
#   'distributor': 'Eros International',
#   'domestic_gross': 3066100,
#   'worldwide_gross': 17870077,
#   'opening_gross': 1326267,
#   'widest_release': 238,
#   'release_date': datetime.datetime(2015, 6, 5, 0, 0)},
#  {'title': 'Ladrones',
#   'budget': None,
#   'runtime': 97,
#   'rating': 'PG-13',
#   'genres': 'Comedy',
#   'distributor': 'Lionsgate',
#   'domestic_gross': 3063505,
#   'worldwide_gross': 3504414,
#   'opening_gross': 1411031,
#   'widest_release': 375,
#   'release_date': datetime.datetime(2015, 10, 9, 0, 0)},
#  {'title': 'Tanu Weds Manu Returns',
#   'budget': None,
#   'runtime': 128,
#   'rating': None,
#   'genres': 'Comedy Drama Romance',
#   'distributor': 'Eros International',
#   'domestic_gross': 3043479,
#   'worldwide_gross': 4180081,
#   'opening_gross': 1006476,
#   'widest_release': 136,
#   'release_date': datetime.datetime(2015, 5, 22, 0, 0)},
#  {'title': 'Rock the Kasbah',
#   'budget': None,
#   'runtime': 106,
#   'rating': 'R',
#   'genres': 'Comedy Music War',
#   'distributor': 'Open Road Films (II)',
#   'domestic_gross': 3020664,
#   'worldwide_gross': 3394174,
#   'opening_gross': 1470592,
#   'widest_release': 2012,
#   'release_date': datetime.datetime(2015, 10, 23, 0, 0)},
#  {'title': 'The End of the Tour',
#   'budget': None,
#   'runtime': 106,
#   'rating': 'R',
#   'genres': 'Biography Drama',
#   'distributor': 'A24',
#   'domestic_gross': 3002884,
#   'worldwide_gross': 3072991,
#   'opening_gross': 123238,
#   'widest_release': 355,
#   'release_date': datetime.datetime(2015, 7, 31, 0, 0)},
#  {'title': 'Wild Tales',
#   'budget': None,
#   'runtime': 122,
#   'rating': 'R',
#   'genres': 'Comedy Drama Thriller',
#   'distributor': 'Sony Pictures Classics',
#   'domestic_gross': 3106530,
#   'worldwide_gross': 30642704,
#   'opening_gross': 85100,
#   'widest_release': 122,
#   'release_date': datetime.datetime(2015, 2, 20, 0, 0)},
#  {'title': 'Horrible Bosses 2',
#   'budget': 42000000,
#   'runtime': 108,
#   'rating': 'R',
#   'genres': 'Comedy Crime',
#   'distributor': 'Warner Bros.',
#   'domestic_gross': 54445357,
#   'worldwide_gross': 107645357,
#   'opening_gross': 15457418,
#   'widest_release': 3400,
#   'release_date': datetime.datetime(2014, 11, 26, 0, 0)},
#  {'title': 'He Named Me Malala',
#   'budget': None,
#   'runtime': 88,
#   'rating': 'PG-13',
#   'genres': 'Biography Documentary',
#   'distributor': 'Fox Searchlight Pictures',
#   'domestic_gross': 2668936,
#   'worldwide_gross': 3433606,
#   'opening_gross': 61808,
#   'widest_release': 477,
#   'release_date': datetime.datetime(2015, 10, 2, 0, 0)},
#  {'title': 'Captive',
#   'budget': None,
#   'runtime': 97,
#   'rating': 'PG-13',
#   'genres': 'Action Biography Crime Drama History Thriller',
#   'distributor': 'Paramount Pictures',
#   'domestic_gross': 2583301,
#   'worldwide_gross': 2801508,
#   'opening_gross': 1393243,
#   'widest_release': 807,
#   'release_date': datetime.datetime(2015, 9, 18, 0, 0)},
#  {'title': 'Chi-Raq',
#   'budget': None,
#   'runtime': 127,
#   'rating': 'R',
#   'genres': 'Comedy Crime Drama Musical',
#   'distributor': 'Roadside Attractions',
#   'domestic_gross': 2653032,
#   'worldwide_gross': 2719699,
#   'opening_gross': 1198453,
#   'widest_release': 305,
#   'release_date': datetime.datetime(2015, 12, 4, 0, 0)},
#  {'title': 'The Interview',
#   'budget': None,
#   'runtime': 112,
#   'rating': 'R',
#   'genres': 'Action Adventure Comedy',
#   'distributor': 'Sony Pictures Entertainment (SPE)',
#   'domestic_gross': 6105175,
#   'worldwide_gross': 11782625,
#   'opening_gross': 1794666,
#   'widest_release': 581,
#   'release_date': datetime.datetime(2014, 12, 25, 0, 0)},
#  {'title': 'Truth',
#   'budget': None,
#   'runtime': 125,
#   'rating': 'R',
#   'genres': 'Biography Drama History Thriller',
#   'distributor': 'Sony Pictures Classics',
#   'domestic_gross': 2541854,
#   'worldwide_gross': 5383097,
#   'opening_gross': 66232,
#   'widest_release': 1122,
#   'release_date': datetime.datetime(2015, 10, 16, 0, 0)},
#  {'title': 'Mistress America',
#   'budget': None,
#   'runtime': 84,
#   'rating': 'R',
#   'genres': 'Comedy Drama',
#   'distributor': 'Fox Searchlight Pictures',
#   'domestic_gross': 2500431,
#   'worldwide_gross': 3340737,
#   'opening_gross': 93206,
#   'widest_release': 512,
#   'release_date': datetime.datetime(2015, 8, 14, 0, 0)},
#  {'title': 'Pawn Sacrifice',
#   'budget': None,
#   'runtime': 115,
#   'rating': 'PG-13',
#   'genres': 'Biography Drama Sport Thriller',
#   'distributor': 'Bleecker Street Media',
#   'domestic_gross': 2436633,
#   'worldwide_gross': 5578519,
#   'opening_gross': 202053,
#   'widest_release': 781,
#   'release_date': datetime.datetime(2015, 9, 16, 0, 0)},
#  {'title': 'The Oscar Nominated Short Films 2015: Live Action',
#   'budget': None,
#   'runtime': 118,
#   'rating': None,
#   'genres': 'Drama',
#   'distributor': 'Shorts International',
#   'domestic_gross': 2412593,
#   'worldwide_gross': 2412593,
#   'opening_gross': 416850,
#   'widest_release': 280,
#   'release_date': datetime.datetime(2015, 1, 30, 0, 0)},
#  {'title': 'Meru',
#   'budget': None,
#   'runtime': 90,
#   'rating': 'R',
#   'genres': 'Documentary Sport',
#   'distributor': 'Music Box Films',
#   'domestic_gross': 2334228,
#   'worldwide_gross': 2334228,
#   'opening_gross': 91279,
#   'widest_release': 176,
#   'release_date': datetime.datetime(2015, 8, 14, 0, 0)}]

# %%
#master_df = pd.DataFrame(movies_list)  #convert list of dict to df
#master_df.set_index('title', inplace=True) #indexing by movie title

#master_df
# Out:
#                                                         budget  runtime  \
# title
# title
# Avengers: Endgame                                            4662   2019-04-26
# The Lion King                                                4802   2019-07-19
# Toy Story 4                                                  4575   2019-06-21
# Frozen II                                                    4440   2019-11-22
# Captain Marvel                                               4310   2019-03-08
# ...                                                           ...          ...
# Truth                                                        1122   2015-10-16
# Mistress America                                              512   2015-08-14
# Pawn Sacrifice                                                781   2015-09-16
# The Oscar Nominated Short Films 2015: Live Action             280   2015-01-30
# Meru                                                          176   2015-08-14
#
# [1000 rows x 10 columns]

# %%
#df1 = master_df.to_csv('/Users/hernantrujillo/Documents/Metis/NBM_Regression_Student-main/Movies_Project_Hernan/data_project/df1.csv')

# %% [markdown]
# ### Daytime (Seasons)

# %%
df1 = pd.read_csv('/Users/hernantrujillo/Documents/Metis/NBM_Regression_Student-main/Movies_Project_Hernan/data_project/df1.csv')

# %%
df1.shape
# Out:
# (580, 12)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            1000 non-null   object
#  1   budget           596 non-null    float64
#  2   runtime          972 non-null    float64
#  3   rating           949 non-null    object
#  4   genres           1000 non-null   object
#  5   distributor      999 non-null    object
#  6   domestic_gross   1000 non-null   int64
#  7   worldwide_gross  1000 non-null   int64
#  8   opening_gross    992 non-null    float64
#  9   widest_release   1000 non-null   int64
#  10  release_date     1000 non-null   object
# dtypes: float64(3), int64(3), object(5)
# memory usage: 86.1+ KB

# %%
#using .isna() result as data mask

df1.isna().sum()
# Out:
# title                0
# budget             404
# runtime             28
# rating              51
# genres               0
# distributor          1
# domestic_gross       0
# worldwide_gross      0
# opening_gross        8
# widest_release       0
# release_date         0
# dtype: int64

# %%
df1.head()
# Out:
#                title       budget  runtime rating  \
# 0  Avengers: Endgame  356000000.0    181.0  PG-13
# 1      The Lion King  260000000.0    118.0     PG
# 2        Toy Story 4  200000000.0    100.0      G
# 3          Frozen II  150000000.0    103.0     PG
# 4     Captain Marvel  160000000.0    123.0  PG-13
#
#                                               genres  \
# 0                      Action Adventure Drama Sci-Fi
# 1           Adventure Animation Drama Family Musical
# 2          Adventure Animation Comedy Family Fantasy
# 3  Adventure Animation Comedy Family Fantasy Musical
# 4                            Action Adventure Sci-Fi
#
#                            distributor  domestic_gross  worldwide_gross  \
# 0  Walt Disney Studios Motion Pictures       858373000       2797501328
# 1  Walt Disney Studios Motion Pictures       543638043       1656943394
# 2  Walt Disney Studios Motion Pictures       434038008       1073394593
# 3  Walt Disney Studios Motion Pictures       477373578       1450026933
# 4  Walt Disney Studios Motion Pictures       426829839       1128274794
#
#    opening_gross  widest_release release_date
# 0    357115007.0            4662   2019-04-26
# 1    191770759.0            4802   2019-07-19
# 2    120908065.0            4575   2019-06-21
# 3    130263358.0            4440   2019-11-22
# 4    153433423.0            4310   2019-03-08

# %%
df1['release_date'] =  pd.to_datetime(df1['release_date'], infer_datetime_format=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            1000 non-null   object
#  1   budget           596 non-null    float64
#  2   runtime          972 non-null    float64
#  3   rating           949 non-null    object
#  4   genres           1000 non-null   object
#  5   distributor      999 non-null    object
#  6   domestic_gross   1000 non-null   int64
#  7   worldwide_gross  1000 non-null   int64
#  8   opening_gross    992 non-null    float64
#  9   widest_release   1000 non-null   int64
#  10  release_date     1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(3), object(4)
# memory usage: 86.1+ KB

# %%
#now, let's group datetime by season so we can use it as a feature

def date_to_season(date):
    Winter = [12, 1, 2]
    Spring = [3, 4, 5]
    Summer = [6, 7, 8]
    Fall = [9, 10, 11]
    if date.month in Winter:
        return "Winter"
    elif date.month in Spring:
        return "Spring"
    elif date.month in Summer:
        return "Summer"
    else:
        return "Fall"

# %%
df1['season'] = df1['release_date'].apply(date_to_season)

# %%
df1.head()
# Out:
#                title       budget  runtime rating  \
# 0  Avengers: Endgame  356000000.0    181.0  PG-13
# 1      The Lion King  260000000.0    118.0     PG
# 2        Toy Story 4  200000000.0    100.0      G
# 3          Frozen II  150000000.0    103.0     PG
# 4     Captain Marvel  160000000.0    123.0  PG-13
#
#                                               genres  \
# 0                      Action Adventure Drama Sci-Fi
# 1           Adventure Animation Drama Family Musical
# 2          Adventure Animation Comedy Family Fantasy
# 3  Adventure Animation Comedy Family Fantasy Musical
# 4                            Action Adventure Sci-Fi
#
#                            distributor  domestic_gross  worldwide_gross  \
# 0  Walt Disney Studios Motion Pictures       858373000       2797501328
# 1  Walt Disney Studios Motion Pictures       543638043       1656943394
# 2  Walt Disney Studios Motion Pictures       434038008       1073394593
# 3  Walt Disney Studios Motion Pictures       477373578       1450026933
# 4  Walt Disney Studios Motion Pictures       426829839       1128274794
#
#    opening_gross  widest_release release_date  season
# 0    357115007.0            4662   2019-04-26  Spring
# 1    191770759.0            4802   2019-07-19  Summer
# 2    120908065.0            4575   2019-06-21  Summer
# 3    130263358.0            4440   2019-11-22    Fall
# 4    153433423.0            4310   2019-03-08  Spring

# %%
#set the title as index

df1.set_index('title', inplace=True)

# %%
df1.head()
# Out:
#                         budget  runtime rating  \
# title
# Avengers: Endgame  356000000.0    181.0  PG-13
# The Lion King      260000000.0    118.0     PG
# Toy Story 4        200000000.0    100.0      G
# Frozen II          150000000.0    103.0     PG
# Captain Marvel     160000000.0    123.0  PG-13
#
#                                                               genres  \
# title
# Avengers: Endgame                      Action Adventure Drama Sci-Fi
# The Lion King               Adventure Animation Drama Family Musical
# Toy Story 4                Adventure Animation Comedy Family Fantasy
# Frozen II          Adventure Animation Comedy Family Fantasy Musical
# Captain Marvel                               Action Adventure Sci-Fi
#
#                                            distributor  domestic_gross  \
# title
# Avengers: Endgame  Walt Disney Studios Motion Pictures       858373000
# The Lion King      Walt Disney Studios Motion Pictures       543638043
# Toy Story 4        Walt Disney Studios Motion Pictures       434038008
# Frozen II          Walt Disney Studios Motion Pictures       477373578
# Captain Marvel     Walt Disney Studios Motion Pictures       426829839
#
#                    worldwide_gross  opening_gross  widest_release  \
# title
# Avengers: Endgame       2797501328    357115007.0            4662
# The Lion King           1656943394    191770759.0            4802
# Toy Story 4             1073394593    120908065.0            4575
# Frozen II               1450026933    130263358.0            4440
# Captain Marvel          1128274794    153433423.0            4310
#
#                   release_date  season
# title
# Avengers: Endgame   2019-04-26  Spring
# The Lion King       2019-07-19  Summer
# Toy Story 4         2019-06-21  Summer
# Frozen II           2019-11-22    Fall
# Captain Marvel      2019-03-08  Spring
